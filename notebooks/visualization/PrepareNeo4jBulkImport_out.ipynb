# %% [markdown]
# # PrepareNeo4jBulkImport
# This notebook uses metadata to prepare CSV Files for Neo4j Bulk Data Import
#
# Author: Peter W. Rose (pwrose@ucsd.edu)

# %%
import os
from os import walk
from os.path import join
import pandas as pd
import numpy as np
from utils import create_node_headers, create_relationship_headers, get_node_data_headers, get_relationship_data_headers, create_meta_node, create_meta_relationship

# %%
# reload modules before executing user code
# %load_ext autoreload
# %autoreload 2

# %%
# configure pandas dataframe
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns
pd.set_option("display.max_colwidth", None)

# %% [markdown]
# ## Specify working directories

# %% [markdown]
# If NEO4J_HOME directory is not set, this notebook creates the example_results/import directory as a proxy for a Neo4j import directory.

# %%
NEO4J_HOME = os.getenv("NEO4J_HOME", default="../example_results")

# %% [markdown]
# Location of Neo4j import directory

# %%
NEO4J_IMPORT = os.path.join(NEO4J_HOME, "import")

# %% [markdown]
# Create the example_results/import directory for testing the example provided in this repo.

# %%
if NEO4J_HOME == "../example_results":
    os.makedirs(os.path.join(NEO4J_IMPORT), exist_ok=True)

# %% [markdown]
# Locations of metadata files (Defaults are files for testing this notebook)

# %%
METADATA = os.getenv("NEO4J_METADATA", default="../example_metadata/")
NODE_METADATA = os.path.join(METADATA, "nodes")
RELATIONSHIP_METADATA = os.path.join(METADATA, "relationships")

# %% [markdown]
# Locations of data files (Defaults are files for testing this notebook)

# %%
DATA = os.getenv("NEO4J_DATA", default="../example_data/")
NODE_DATA = os.path.join(DATA, "nodes")
RELATIONSHIP_DATA = os.path.join(DATA, "relationships")

# %% [markdown]
# ## Create headers from metadata files

# %% [markdown]
# Create the node name, the expected node file header, and the Neo4j header for bulk import from the metadata files.

# %%
dirpath, _, filenames = next(walk(NODE_METADATA))
node_headers = [create_node_headers(dirpath, filename) for filename in filenames]

# %%
node_metadata = pd.DataFrame(node_headers)

# %%
node_metadata
# Out:
#                   node  \
# 0             Software
# 1         Organization
# 2               Patent
# 3   ResearchInitiative
# 4         Presentation
# 5          Publication
# 6           Researcher
# 7                Event
# 8              Dataset
# 9   FundingOpportunity
# 10               Grant
#
#                                                                          metadataHeader  \
# 0                                                               id,name,description,url
# 1                                  id,name,city,state,country,ror,uei,duns,geonames,url
# 2                        id,name,inventors,filingDate,grantedDate,status,applicants,url
# 3                       id,name,longName,description,researchInitiativeUrl,url,websites
# 4                                           id,name,presenters,presentationUrl,videoUrl
# 5                                 id,name,abstract,journal,year,type,doi,pmId,pmcId,url
# 6                        id,name,fullName,firstName,middleName,lastName,orcid,profileId
# 7                       id,name,eventType,eventUrl,startDate,endDate,city,state,country
# 8                                                                           id,name,url
# 9                                                                           id,name,url
# 10  id,name,abstract,narrative,fundingMechanism,awardCode,researchInitiative,subProject
#
#                                                                                                                                          importHeader  \
# 0                                                                                        id:ID(Software-ID),name:string,description:string,url:string
# 1             id:ID(Organization-ID),name:string,city:string,state:string,country:string,ror:string,uei:string,duns:string,geonames:string,url:string
# 2                       id:ID(Patent-ID),name:string,inventors:string[],filingDate:date,grantedDate:date,status:string,applicants:string[],url:string
# 3               id:ID(ResearchInitiative-ID),name:string,longName:string,description:string,researchInitiativeUrl:string,url:string,websites:string[]
# 4                                                         id:ID(Presentation-ID),name:string,presenters:string,presentationUrl:string,videoUrl:string
# 5                id:ID(Publication-ID),name:string,abstract:string,journal:string,year:int,type:string,doi:string,pmId:string,pmcId:string,url:string
# 6                   id:ID(Researcher-ID),name:string,fullName:string,firstName:string,middleName:string,lastName:string,orcid:string,profileId:string
# 7                    id:ID(Event-ID),name:string,eventType:string,eventUrl:string,startDate:date,endDate:date,city:string,state:string,country:string
# 8                                                                                                            id:ID(Dataset-ID),name:string,url:string
# 9                                                                                                 id:ID(FundingOpportunity-ID),name:string,url:string
# 10  id:ID(Grant-ID),name:string,abstract:string,narrative:string,fundingMechanism:string,awardCode:string,researchInitiative:string,subProject:string
#
#                                                                      metadataPath
# 0             /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Software.csv
# 1         /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Organization.csv
# 2               /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Patent.csv
# 3   /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/ResearchInitiative.csv
# 4         /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Presentation.csv
# 5          /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Publication.csv
# 6           /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Researcher.csv
# 7                /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Event.csv
# 8              /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Dataset.csv
# 9   /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/FundingOpportunity.csv
# 10               /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Grant.csv

# %% [markdown]
# Create the relationship name, the expected relatinonship file header, and the Neo4j header for bulk import from the metadata files.

# %%
dirpath, _, filenames = next(walk(RELATIONSHIP_METADATA))
relationship_headers = [create_relationship_headers(dirpath, filename) for filename in filenames]

# %%
relationship_metadata = pd.DataFrame(relationship_headers)

# %%
relationship_metadata
# Out:
#           relationship                                metadataHeader  \
# 0            SUPPORTED                                       from,to
# 1            DEVELOPED                                       from,to
# 2                CITES                                       from,to
# 3               FUNDED                                       from,to
# 4         PRESENTED_AT                                       from,to
# 5              CREATED                                       from,to
# 6             PROVIDES                                       from,to
# 7          EMPLOYED_AT                           from,to,lastUpdated
# 8                 USED                                       from,to
# 9          IS_INVENTOR                                       from,to
# 10            AUTHORED                                       from,to
# 11  IS_INVESTIGATOR_OF  from,to,isPi,isContactPi,isStudyInvestigator
# 12           PRESENTED                                       from,to
#
#                                                                                                importHeader  \
# 0                                                        :START_ID(ResearchInitiative-ID),:END_ID(Grant-ID)
# 1                                                             :START_ID(Researcher-ID),:END_ID(Software-ID)
# 2                                                         :START_ID(Publication-ID),:END_ID(Publication-ID)
# 3                                                        :START_ID(Grant-ID),:END_ID(ResearchInitiative-ID)
# 4                                                              :START_ID(Presentation-ID),:END_ID(Event-ID)
# 5                                                              :START_ID(Researcher-ID),:END_ID(Dataset-ID)
# 6                                                        :START_ID(FundingOpportunity-ID),:END_ID(Grant-ID)
# 7                                         :START_ID(Researcher-ID),:END_ID(Organization-ID),lastUpdated:int
# 8                                                              :START_ID(Researcher-ID),:END_ID(Dataset-ID)
# 9                                                               :START_ID(Researcher-ID),:END_ID(Patent-ID)
# 10                                                         :START_ID(Researcher-ID),:END_ID(Publication-ID)
# 11  :START_ID(Researcher-ID),:END_ID(Grant-ID),isPi:boolean,isContactPi:boolean,isStudyInvestigator:boolean
# 12                                                        :START_ID(Researcher-ID),:END_ID(Presentation-ID)
#
#                 source              target  \
# 0   ResearchInitiative               Grant
# 1           Researcher            Software
# 2          Publication         Publication
# 3                Grant  ResearchInitiative
# 4         Presentation               Event
# 5           Researcher             Dataset
# 6   FundingOpportunity               Grant
# 7           Researcher        Organization
# 8           Researcher             Dataset
# 9           Researcher              Patent
# 10          Researcher         Publication
# 11          Researcher               Grant
# 12          Researcher        Presentation
#
#                                                                                               metadataPath
# 0    /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/ResearchInitiative-SUPPORTED-Grant.csv
# 1         /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-DEVELOPED-Software.csv
# 2         /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Publication-CITES-Publication.csv
# 3       /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Grant-FUNDED-ResearchInitiative.csv
# 4       /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Presentation-PRESENTED_AT-Event.csv
# 5            /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-CREATED-Dataset.csv
# 6     /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/FundingOpportunity-PROVIDES-Grant.csv
# 7   /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-EMPLOYED_AT-Organization.csv
# 8               /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-USED-Dataset.csv
# 9         /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-IS_INVENTOR-Patent.csv
# 10      /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-AUTHORED-Publication.csv
# 11  /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-IS_INVESTIGATOR_OF-Grant.csv
# 12    /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-PRESENTED-Presentation.csv

# %% [markdown]
# ## Add constraints and indices for Nodes

# %%
def get_string_properties(row):
    node = row["node"]
    header = row["importHeader"]
    fields = header.split(",")
    fields = filter(lambda field: field.endswith(":string"), fields)
    string_properties = []
    
    for field in fields:
        field_name = field.split(":")[0]
        string_properties.append(field_name)

    return string_properties

# %%
node_metadata["stringProperties"] = node_metadata.apply(get_string_properties, axis=1)

# %%
def add_index(row):
    node = row["node"]
    properties = row["stringProperties"]
    indices = f"CREATE CONSTRAINT {node} FOR (n:{node}) REQUIRE n.id IS UNIQUE;"
    
    for prop in properties:
        indices += f"CREATE INDEX {node}_{prop} FOR (n:{node}) ON (n.{prop});"
        #indices += f"CREATE FULLTEXT INDEX FOR (n:{node}) ON EACH [n.{prop}];"

    return indices

# %%
node_metadata["index"] = node_metadata.apply(add_index, axis=1)

# %%
node_metadata.head()
# Out:
#                  node  \
# 0            Software
# 1        Organization
# 2              Patent
# 3  ResearchInitiative
# 4        Presentation
#
#                                                     metadataHeader  \
# 0                                          id,name,description,url
# 1             id,name,city,state,country,ror,uei,duns,geonames,url
# 2   id,name,inventors,filingDate,grantedDate,status,applicants,url
# 3  id,name,longName,description,researchInitiativeUrl,url,websites
# 4                      id,name,presenters,presentationUrl,videoUrl
#
#                                                                                                                               importHeader  \
# 0                                                                             id:ID(Software-ID),name:string,description:string,url:string
# 1  id:ID(Organization-ID),name:string,city:string,state:string,country:string,ror:string,uei:string,duns:string,geonames:string,url:string
# 2            id:ID(Patent-ID),name:string,inventors:string[],filingDate:date,grantedDate:date,status:string,applicants:string[],url:string
# 3    id:ID(ResearchInitiative-ID),name:string,longName:string,description:string,researchInitiativeUrl:string,url:string,websites:string[]
# 4                                              id:ID(Presentation-ID),name:string,presenters:string,presentationUrl:string,videoUrl:string
#
#                                                                     metadataPath  \
# 0            /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Software.csv
# 1        /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Organization.csv
# 2              /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Patent.csv
# 3  /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/ResearchInitiative.csv
# 4        /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Presentation.csv
#
#                                               stringProperties  \
# 0                                     [name, description, url]
# 1  [name, city, state, country, ror, uei, duns, geonames, url]
# 2                                          [name, status, url]
# 3    [name, longName, description, researchInitiativeUrl, url]
# 4                [name, presenters, presentationUrl, videoUrl]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    index
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                CREATE CONSTRAINT Software FOR (n:Software) REQUIRE n.id IS UNIQUE;CREATE INDEX Software_name FOR (n:Software) ON (n.name);CREATE INDEX Software_description FOR (n:Software) ON (n.description);CREATE INDEX Software_url FOR (n:Software) ON (n.url);
# 1  CREATE CONSTRAINT Organization FOR (n:Organization) REQUIRE n.id IS UNIQUE;CREATE INDEX Organization_name FOR (n:Organization) ON (n.name);CREATE INDEX Organization_city FOR (n:Organization) ON (n.city);CREATE INDEX Organization_state FOR (n:Organization) ON (n.state);CREATE INDEX Organization_country FOR (n:Organization) ON (n.country);CREATE INDEX Organization_ror FOR (n:Organization) ON (n.ror);CREATE INDEX Organization_uei FOR (n:Organization) ON (n.uei);CREATE INDEX Organization_duns FOR (n:Organization) ON (n.duns);CREATE INDEX Organization_geonames FOR (n:Organization) ON (n.geonames);CREATE INDEX Organization_url FOR (n:Organization) ON (n.url);
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                          CREATE CONSTRAINT Patent FOR (n:Patent) REQUIRE n.id IS UNIQUE;CREATE INDEX Patent_name FOR (n:Patent) ON (n.name);CREATE INDEX Patent_status FOR (n:Patent) ON (n.status);CREATE INDEX Patent_url FOR (n:Patent) ON (n.url);
# 3                                                                                                                                              CREATE CONSTRAINT ResearchInitiative FOR (n:ResearchInitiative) REQUIRE n.id IS UNIQUE;CREATE INDEX ResearchInitiative_name FOR (n:ResearchInitiative) ON (n.name);CREATE INDEX ResearchInitiative_longName FOR (n:ResearchInitiative) ON (n.longName);CREATE INDEX ResearchInitiative_description FOR (n:ResearchInitiative) ON (n.description);CREATE INDEX ResearchInitiative_researchInitiativeUrl FOR (n:ResearchInitiative) ON (n.researchInitiativeUrl);CREATE INDEX ResearchInitiative_url FOR (n:ResearchInitiative) ON (n.url);
# 4                                                                                                                                                                                                                                                                                                  CREATE CONSTRAINT Presentation FOR (n:Presentation) REQUIRE n.id IS UNIQUE;CREATE INDEX Presentation_name FOR (n:Presentation) ON (n.name);CREATE INDEX Presentation_presenters FOR (n:Presentation) ON (n.presenters);CREATE INDEX Presentation_presentationUrl FOR (n:Presentation) ON (n.presentationUrl);CREATE INDEX Presentation_videoUrl FOR (n:Presentation) ON (n.videoUrl);

# %% [markdown]
# ## Get headers from data files

# %% [markdown]
# Node data files

# %%
dirpath, _, filenames = next(walk(NODE_DATA))
csv_files = filter(lambda name: name.endswith(".csv"), filenames)
data_headers = [get_node_data_headers(dirpath, filename) for filename in csv_files]
# Out:
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes Organization.csv
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes Publication_primary.csv
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes Researcher_investigators.csv
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes Patent.csv
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes Researcher_manually.csv
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes Dataset_manually.csv
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes ResearchInitiative.csv
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes Presentation.csv
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes Software_manually.csv
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes Publication_secondary.csv
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes Event.csv
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes Dataset.csv
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes FundingOpportunity.csv
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes Researcher_primary_coauthors.csv
# Node Data /Users/Peter/GitRepositories/radx-kg/kg/data/nodes Grant.csv

# %%
node_data = pd.DataFrame(data_headers)

# %%
node_data
# Out:
#                   node  \
# 0         Organization
# 1          Publication
# 2           Researcher
# 3               Patent
# 4           Researcher
# 5              Dataset
# 6   ResearchInitiative
# 7         Presentation
# 8             Software
# 9          Publication
# 10               Event
# 11             Dataset
# 12  FundingOpportunity
# 13          Researcher
# 14               Grant
#
#                                                                              dataHeader  \
# 0                                  id,name,city,state,country,ror,uei,duns,geonames,url
# 1                                 id,name,abstract,journal,year,type,doi,pmId,pmcId,url
# 2                        id,name,fullName,firstName,middleName,lastName,orcid,profileId
# 3                        id,name,inventors,filingDate,grantedDate,status,applicants,url
# 4                        id,name,fullName,firstName,middleName,lastName,orcid,profileId
# 5                                                                           id,name,url
# 6                       id,name,longName,description,researchInitiativeUrl,url,websites
# 7                                           id,name,presenters,presentationUrl,videoUrl
# 8                                                               id,name,description,url
# 9                                 id,name,abstract,journal,year,type,doi,pmId,pmcId,url
# 10                      id,name,eventType,eventUrl,startDate,endDate,city,state,country
# 11                                                                          id,name,url
# 12                                                                          id,name,url
# 13                       id,name,fullName,firstName,middleName,lastName,orcid,profileId
# 14  id,name,abstract,narrative,fundingMechanism,awardCode,researchInitiative,subProject
#
#                                                                                dataPath
# 0                   /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Organization.csv
# 1            /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Publication_primary.csv
# 2       /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Researcher_investigators.csv
# 3                         /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Patent.csv
# 4            /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Researcher_manually.csv
# 5               /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Dataset_manually.csv
# 6             /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/ResearchInitiative.csv
# 7                   /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Presentation.csv
# 8              /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Software_manually.csv
# 9          /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Publication_secondary.csv
# 10                         /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Event.csv
# 11                       /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Dataset.csv
# 12            /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/FundingOpportunity.csv
# 13  /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Researcher_primary_coauthors.csv
# 14                         /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Grant.csv

# %% [markdown]
# Relationship data files

# %%
dirpath, _, filenames = next(walk(RELATIONSHIP_DATA))
csv_files = filter(lambda name: name.endswith(".csv"), filenames)
data_headers = [get_relationship_data_headers(dirpath, filename) for filename in csv_files]
# Out:
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships ResearchInitiative-SUPPORTED-Grant.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships Researcher-DEVELOPED-Software.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships Publication-CITES-Publication.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships Grant-FUNDED-ResearchInitiative.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships Researcher-CREATED-Dataset_manually.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships Researcher-AUTHORED-Publication_investigators.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships Presentation-PRESENTED_AT-Event.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships Researcher-CREATED-Dataset.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships FundingOpportunity-PROVIDES-Grant.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships Researcher-EMPLOYED_AT-Organization.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships Researcher-USED-Dataset.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships Researcher-IS_INVENTOR-Patent.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships Researcher-IS_INVESTIGATOR_OF-Grant.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships Researcher-IS_INVESTIGATOR_OF-Grant_manually.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships Researcher-PRESENTED-Presentation.csv
# Relationship Data /Users/Peter/GitRepositories/radx-kg/kg/data/relationships Researcher-AUTHORED-Publication_other.csv

# %%
relationship_data = pd.DataFrame(data_headers)

# %%
relationship_data
# Out:
#           relationship                                    dataHeader  \
# 0            SUPPORTED                                       from,to
# 1            DEVELOPED                                       from,to
# 2                CITES                                       from,to
# 3               FUNDED                                       from,to
# 4              CREATED                                       from,to
# 5             AUTHORED                                       from,to
# 6         PRESENTED_AT                                       from,to
# 7              CREATED                                       from,to
# 8             PROVIDES                                       from,to
# 9          EMPLOYED_AT                           from,to,lastUpdated
# 10                USED                                       from,to
# 11         IS_INVENTOR                                       from,to
# 12  IS_INVESTIGATOR_OF  from,to,isPi,isContactPi,isStudyInvestigator
# 13  IS_INVESTIGATOR_OF  from,to,isPi,isContactPi,isStudyInvestigator
# 14           PRESENTED                                       from,to
# 15            AUTHORED                                       from,to
#
#                                                                                                         dataPath
# 0              /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/ResearchInitiative-SUPPORTED-Grant.csv
# 1                   /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-DEVELOPED-Software.csv
# 2                   /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Publication-CITES-Publication.csv
# 3                 /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Grant-FUNDED-ResearchInitiative.csv
# 4             /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-CREATED-Dataset_manually.csv
# 5   /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-AUTHORED-Publication_investigators.csv
# 6                 /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Presentation-PRESENTED_AT-Event.csv
# 7                      /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-CREATED-Dataset.csv
# 8               /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/FundingOpportunity-PROVIDES-Grant.csv
# 9             /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-EMPLOYED_AT-Organization.csv
# 10                        /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-USED-Dataset.csv
# 11                  /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-IS_INVENTOR-Patent.csv
# 12            /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-IS_INVESTIGATOR_OF-Grant.csv
# 13   /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-IS_INVESTIGATOR_OF-Grant_manually.csv
# 14              /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-PRESENTED-Presentation.csv
# 15          /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-AUTHORED-Publication_other.csv

# %% [markdown]
# ## Merge metadata with data

# %%
matched_nodes = node_data.merge(node_metadata, on="node", how="outer")
matched_nodes["match"] = matched_nodes["dataHeader"] == matched_nodes["metadataHeader"]
matched_nodes.fillna("", inplace=True)

# %%
matched_nodes
# Out:
#                   node  \
# 0         Organization
# 1          Publication
# 2          Publication
# 3           Researcher
# 4           Researcher
# 5           Researcher
# 6               Patent
# 7              Dataset
# 8              Dataset
# 9   ResearchInitiative
# 10        Presentation
# 11            Software
# 12               Event
# 13  FundingOpportunity
# 14               Grant
#
#                                                                              dataHeader  \
# 0                                  id,name,city,state,country,ror,uei,duns,geonames,url
# 1                                 id,name,abstract,journal,year,type,doi,pmId,pmcId,url
# 2                                 id,name,abstract,journal,year,type,doi,pmId,pmcId,url
# 3                        id,name,fullName,firstName,middleName,lastName,orcid,profileId
# 4                        id,name,fullName,firstName,middleName,lastName,orcid,profileId
# 5                        id,name,fullName,firstName,middleName,lastName,orcid,profileId
# 6                        id,name,inventors,filingDate,grantedDate,status,applicants,url
# 7                                                                           id,name,url
# 8                                                                           id,name,url
# 9                       id,name,longName,description,researchInitiativeUrl,url,websites
# 10                                          id,name,presenters,presentationUrl,videoUrl
# 11                                                              id,name,description,url
# 12                      id,name,eventType,eventUrl,startDate,endDate,city,state,country
# 13                                                                          id,name,url
# 14  id,name,abstract,narrative,fundingMechanism,awardCode,researchInitiative,subProject
#
#                                                                                dataPath  \
# 0                   /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Organization.csv
# 1            /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Publication_primary.csv
# 2          /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Publication_secondary.csv
# 3       /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Researcher_investigators.csv
# 4            /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Researcher_manually.csv
# 5   /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Researcher_primary_coauthors.csv
# 6                         /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Patent.csv
# 7               /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Dataset_manually.csv
# 8                        /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Dataset.csv
# 9             /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/ResearchInitiative.csv
# 10                  /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Presentation.csv
# 11             /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Software_manually.csv
# 12                         /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Event.csv
# 13            /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/FundingOpportunity.csv
# 14                         /Users/Peter/GitRepositories/radx-kg/kg/data/nodes/Grant.csv
#
#                                                                          metadataHeader  \
# 0                                  id,name,city,state,country,ror,uei,duns,geonames,url
# 1                                 id,name,abstract,journal,year,type,doi,pmId,pmcId,url
# 2                                 id,name,abstract,journal,year,type,doi,pmId,pmcId,url
# 3                        id,name,fullName,firstName,middleName,lastName,orcid,profileId
# 4                        id,name,fullName,firstName,middleName,lastName,orcid,profileId
# 5                        id,name,fullName,firstName,middleName,lastName,orcid,profileId
# 6                        id,name,inventors,filingDate,grantedDate,status,applicants,url
# 7                                                                           id,name,url
# 8                                                                           id,name,url
# 9                       id,name,longName,description,researchInitiativeUrl,url,websites
# 10                                          id,name,presenters,presentationUrl,videoUrl
# 11                                                              id,name,description,url
# 12                      id,name,eventType,eventUrl,startDate,endDate,city,state,country
# 13                                                                          id,name,url
# 14  id,name,abstract,narrative,fundingMechanism,awardCode,researchInitiative,subProject
#
#                                                                                                                                          importHeader  \
# 0             id:ID(Organization-ID),name:string,city:string,state:string,country:string,ror:string,uei:string,duns:string,geonames:string,url:string
# 1                id:ID(Publication-ID),name:string,abstract:string,journal:string,year:int,type:string,doi:string,pmId:string,pmcId:string,url:string
# 2                id:ID(Publication-ID),name:string,abstract:string,journal:string,year:int,type:string,doi:string,pmId:string,pmcId:string,url:string
# 3                   id:ID(Researcher-ID),name:string,fullName:string,firstName:string,middleName:string,lastName:string,orcid:string,profileId:string
# 4                   id:ID(Researcher-ID),name:string,fullName:string,firstName:string,middleName:string,lastName:string,orcid:string,profileId:string
# 5                   id:ID(Researcher-ID),name:string,fullName:string,firstName:string,middleName:string,lastName:string,orcid:string,profileId:string
# 6                       id:ID(Patent-ID),name:string,inventors:string[],filingDate:date,grantedDate:date,status:string,applicants:string[],url:string
# 7                                                                                                            id:ID(Dataset-ID),name:string,url:string
# 8                                                                                                            id:ID(Dataset-ID),name:string,url:string
# 9               id:ID(ResearchInitiative-ID),name:string,longName:string,description:string,researchInitiativeUrl:string,url:string,websites:string[]
# 10                                                        id:ID(Presentation-ID),name:string,presenters:string,presentationUrl:string,videoUrl:string
# 11                                                                                       id:ID(Software-ID),name:string,description:string,url:string
# 12                   id:ID(Event-ID),name:string,eventType:string,eventUrl:string,startDate:date,endDate:date,city:string,state:string,country:string
# 13                                                                                                id:ID(FundingOpportunity-ID),name:string,url:string
# 14  id:ID(Grant-ID),name:string,abstract:string,narrative:string,fundingMechanism:string,awardCode:string,researchInitiative:string,subProject:string
#
#                                                                      metadataPath  \
# 0         /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Organization.csv
# 1          /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Publication.csv
# 2          /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Publication.csv
# 3           /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Researcher.csv
# 4           /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Researcher.csv
# 5           /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Researcher.csv
# 6               /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Patent.csv
# 7              /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Dataset.csv
# 8              /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Dataset.csv
# 9   /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/ResearchInitiative.csv
# 10        /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Presentation.csv
# 11            /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Software.csv
# 12               /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Event.csv
# 13  /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/FundingOpportunity.csv
# 14               /Users/Peter/GitRepositories/radx-kg/kg/metadata/nodes/Grant.csv
#
#                                                                             stringProperties  \
# 0                                [name, city, state, country, ror, uei, duns, geonames, url]
# 1                                     [name, abstract, journal, type, doi, pmId, pmcId, url]
# 2                                     [name, abstract, journal, type, doi, pmId, pmcId, url]
# 3                        [name, fullName, firstName, middleName, lastName, orcid, profileId]
# 4                        [name, fullName, firstName, middleName, lastName, orcid, profileId]
# 5                        [name, fullName, firstName, middleName, lastName, orcid, profileId]
# 6                                                                        [name, status, url]
# 7                                                                                [name, url]
# 8                                                                                [name, url]
# 9                                  [name, longName, description, researchInitiativeUrl, url]
# 10                                             [name, presenters, presentationUrl, videoUrl]
# 11                                                                  [name, description, url]
# 12                                         [name, eventType, eventUrl, city, state, country]
# 13                                                                               [name, url]
# 14  [name, abstract, narrative, fundingMechanism, awardCode, researchInitiative, subProject]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     index  \
# 0   CREATE CONSTRAINT Organization FOR (n:Organization) REQUIRE n.id IS UNIQUE;CREATE INDEX Organization_name FOR (n:Organization) ON (n.name);CREATE INDEX Organization_city FOR (n:Organization) ON (n.city);CREATE INDEX Organization_state FOR (n:Organization) ON (n.state);CREATE INDEX Organization_country FOR (n:Organization) ON (n.country);CREATE INDEX Organization_ror FOR (n:Organization) ON (n.ror);CREATE INDEX Organization_uei FOR (n:Organization) ON (n.uei);CREATE INDEX Organization_duns FOR (n:Organization) ON (n.duns);CREATE INDEX Organization_geonames FOR (n:Organization) ON (n.geonames);CREATE INDEX Organization_url FOR (n:Organization) ON (n.url);
# 1                                                                                   CREATE CONSTRAINT Publication FOR (n:Publication) REQUIRE n.id IS UNIQUE;CREATE INDEX Publication_name FOR (n:Publication) ON (n.name);CREATE INDEX Publication_abstract FOR (n:Publication) ON (n.abstract);CREATE INDEX Publication_journal FOR (n:Publication) ON (n.journal);CREATE INDEX Publication_type FOR (n:Publication) ON (n.type);CREATE INDEX Publication_doi FOR (n:Publication) ON (n.doi);CREATE INDEX Publication_pmId FOR (n:Publication) ON (n.pmId);CREATE INDEX Publication_pmcId FOR (n:Publication) ON (n.pmcId);CREATE INDEX Publication_url FOR (n:Publication) ON (n.url);
# 2                                                                                   CREATE CONSTRAINT Publication FOR (n:Publication) REQUIRE n.id IS UNIQUE;CREATE INDEX Publication_name FOR (n:Publication) ON (n.name);CREATE INDEX Publication_abstract FOR (n:Publication) ON (n.abstract);CREATE INDEX Publication_journal FOR (n:Publication) ON (n.journal);CREATE INDEX Publication_type FOR (n:Publication) ON (n.type);CREATE INDEX Publication_doi FOR (n:Publication) ON (n.doi);CREATE INDEX Publication_pmId FOR (n:Publication) ON (n.pmId);CREATE INDEX Publication_pmcId FOR (n:Publication) ON (n.pmcId);CREATE INDEX Publication_url FOR (n:Publication) ON (n.url);
# 3                                                                                                                           CREATE CONSTRAINT Researcher FOR (n:Researcher) REQUIRE n.id IS UNIQUE;CREATE INDEX Researcher_name FOR (n:Researcher) ON (n.name);CREATE INDEX Researcher_fullName FOR (n:Researcher) ON (n.fullName);CREATE INDEX Researcher_firstName FOR (n:Researcher) ON (n.firstName);CREATE INDEX Researcher_middleName FOR (n:Researcher) ON (n.middleName);CREATE INDEX Researcher_lastName FOR (n:Researcher) ON (n.lastName);CREATE INDEX Researcher_orcid FOR (n:Researcher) ON (n.orcid);CREATE INDEX Researcher_profileId FOR (n:Researcher) ON (n.profileId);
# 4                                                                                                                           CREATE CONSTRAINT Researcher FOR (n:Researcher) REQUIRE n.id IS UNIQUE;CREATE INDEX Researcher_name FOR (n:Researcher) ON (n.name);CREATE INDEX Researcher_fullName FOR (n:Researcher) ON (n.fullName);CREATE INDEX Researcher_firstName FOR (n:Researcher) ON (n.firstName);CREATE INDEX Researcher_middleName FOR (n:Researcher) ON (n.middleName);CREATE INDEX Researcher_lastName FOR (n:Researcher) ON (n.lastName);CREATE INDEX Researcher_orcid FOR (n:Researcher) ON (n.orcid);CREATE INDEX Researcher_profileId FOR (n:Researcher) ON (n.profileId);
# 5                                                                                                                           CREATE CONSTRAINT Researcher FOR (n:Researcher) REQUIRE n.id IS UNIQUE;CREATE INDEX Researcher_name FOR (n:Researcher) ON (n.name);CREATE INDEX Researcher_fullName FOR (n:Researcher) ON (n.fullName);CREATE INDEX Researcher_firstName FOR (n:Researcher) ON (n.firstName);CREATE INDEX Researcher_middleName FOR (n:Researcher) ON (n.middleName);CREATE INDEX Researcher_lastName FOR (n:Researcher) ON (n.lastName);CREATE INDEX Researcher_orcid FOR (n:Researcher) ON (n.orcid);CREATE INDEX Researcher_profileId FOR (n:Researcher) ON (n.profileId);
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                           CREATE CONSTRAINT Patent FOR (n:Patent) REQUIRE n.id IS UNIQUE;CREATE INDEX Patent_name FOR (n:Patent) ON (n.name);CREATE INDEX Patent_status FOR (n:Patent) ON (n.status);CREATE INDEX Patent_url FOR (n:Patent) ON (n.url);
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             CREATE CONSTRAINT Dataset FOR (n:Dataset) REQUIRE n.id IS UNIQUE;CREATE INDEX Dataset_name FOR (n:Dataset) ON (n.name);CREATE INDEX Dataset_url FOR (n:Dataset) ON (n.url);
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             CREATE CONSTRAINT Dataset FOR (n:Dataset) REQUIRE n.id IS UNIQUE;CREATE INDEX Dataset_name FOR (n:Dataset) ON (n.name);CREATE INDEX Dataset_url FOR (n:Dataset) ON (n.url);
# 9                                                                                                                                               CREATE CONSTRAINT ResearchInitiative FOR (n:ResearchInitiative) REQUIRE n.id IS UNIQUE;CREATE INDEX ResearchInitiative_name FOR (n:ResearchInitiative) ON (n.name);CREATE INDEX ResearchInitiative_longName FOR (n:ResearchInitiative) ON (n.longName);CREATE INDEX ResearchInitiative_description FOR (n:ResearchInitiative) ON (n.description);CREATE INDEX ResearchInitiative_researchInitiativeUrl FOR (n:ResearchInitiative) ON (n.researchInitiativeUrl);CREATE INDEX ResearchInitiative_url FOR (n:ResearchInitiative) ON (n.url);
# 10                                                                                                                                                                                                                                                                                                  CREATE CONSTRAINT Presentation FOR (n:Presentation) REQUIRE n.id IS UNIQUE;CREATE INDEX Presentation_name FOR (n:Presentation) ON (n.name);CREATE INDEX Presentation_presenters FOR (n:Presentation) ON (n.presenters);CREATE INDEX Presentation_presentationUrl FOR (n:Presentation) ON (n.presentationUrl);CREATE INDEX Presentation_videoUrl FOR (n:Presentation) ON (n.videoUrl);
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                CREATE CONSTRAINT Software FOR (n:Software) REQUIRE n.id IS UNIQUE;CREATE INDEX Software_name FOR (n:Software) ON (n.name);CREATE INDEX Software_description FOR (n:Software) ON (n.description);CREATE INDEX Software_url FOR (n:Software) ON (n.url);
# 12                                                                                                                                                                                                                                                                                    CREATE CONSTRAINT Event FOR (n:Event) REQUIRE n.id IS UNIQUE;CREATE INDEX Event_name FOR (n:Event) ON (n.name);CREATE INDEX Event_eventType FOR (n:Event) ON (n.eventType);CREATE INDEX Event_eventUrl FOR (n:Event) ON (n.eventUrl);CREATE INDEX Event_city FOR (n:Event) ON (n.city);CREATE INDEX Event_state FOR (n:Event) ON (n.state);CREATE INDEX Event_country FOR (n:Event) ON (n.country);
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                          CREATE CONSTRAINT FundingOpportunity FOR (n:FundingOpportunity) REQUIRE n.id IS UNIQUE;CREATE INDEX FundingOpportunity_name FOR (n:FundingOpportunity) ON (n.name);CREATE INDEX FundingOpportunity_url FOR (n:FundingOpportunity) ON (n.url);
# 14                                                                                                                                                                CREATE CONSTRAINT Grant FOR (n:Grant) REQUIRE n.id IS UNIQUE;CREATE INDEX Grant_name FOR (n:Grant) ON (n.name);CREATE INDEX Grant_abstract FOR (n:Grant) ON (n.abstract);CREATE INDEX Grant_narrative FOR (n:Grant) ON (n.narrative);CREATE INDEX Grant_fundingMechanism FOR (n:Grant) ON (n.fundingMechanism);CREATE INDEX Grant_awardCode FOR (n:Grant) ON (n.awardCode);CREATE INDEX Grant_researchInitiative FOR (n:Grant) ON (n.researchInitiative);CREATE INDEX Grant_subProject FOR (n:Grant) ON (n.subProject);
#
#     match
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# 10   True
# 11   True
# 12   True
# 13   True
# 14   True

# %%
mismatched_nodes = matched_nodes[(matched_nodes["match"] == False) & (matched_nodes["dataPath"] != "")]
mismatched_nodes
# Out:
# Empty DataFrame
# Columns: [node, dataHeader, dataPath, metadataHeader, importHeader, metadataPath, stringProperties, index, match]
# Index: []

# %%
if mismatched_nodes.shape[0] > 0:
    print("The following node data files do not match the metadata specification:")
    mismatched_nodes.to_csv(os.path.join(NEO4J_IMPORT, "mismatches_n.csv"), index=False)
    
mismatched_nodes
# Out:
# Empty DataFrame
# Columns: [node, dataHeader, dataPath, metadataHeader, importHeader, metadataPath, stringProperties, index, match]
# Index: []

# %%
matched_relationships = relationship_data.merge(relationship_metadata, on="relationship", how="outer")
matched_relationships["match"] = matched_relationships["dataHeader"] == matched_relationships["metadataHeader"]
matched_relationships.fillna("", inplace=True)
matched_relationships["fullRelationship"] = matched_relationships["source"] + "-" + matched_relationships["relationship"] + "-" + matched_relationships["target"]
matched_relationships
# Out:
#           relationship                                    dataHeader  \
# 0            SUPPORTED                                       from,to
# 1            DEVELOPED                                       from,to
# 2                CITES                                       from,to
# 3               FUNDED                                       from,to
# 4              CREATED                                       from,to
# 5              CREATED                                       from,to
# 6             AUTHORED                                       from,to
# 7             AUTHORED                                       from,to
# 8         PRESENTED_AT                                       from,to
# 9             PROVIDES                                       from,to
# 10         EMPLOYED_AT                           from,to,lastUpdated
# 11                USED                                       from,to
# 12         IS_INVENTOR                                       from,to
# 13  IS_INVESTIGATOR_OF  from,to,isPi,isContactPi,isStudyInvestigator
# 14  IS_INVESTIGATOR_OF  from,to,isPi,isContactPi,isStudyInvestigator
# 15           PRESENTED                                       from,to
#
#                                                                                                         dataPath  \
# 0              /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/ResearchInitiative-SUPPORTED-Grant.csv
# 1                   /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-DEVELOPED-Software.csv
# 2                   /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Publication-CITES-Publication.csv
# 3                 /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Grant-FUNDED-ResearchInitiative.csv
# 4             /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-CREATED-Dataset_manually.csv
# 5                      /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-CREATED-Dataset.csv
# 6   /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-AUTHORED-Publication_investigators.csv
# 7           /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-AUTHORED-Publication_other.csv
# 8                 /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Presentation-PRESENTED_AT-Event.csv
# 9               /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/FundingOpportunity-PROVIDES-Grant.csv
# 10            /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-EMPLOYED_AT-Organization.csv
# 11                        /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-USED-Dataset.csv
# 12                  /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-IS_INVENTOR-Patent.csv
# 13            /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-IS_INVESTIGATOR_OF-Grant.csv
# 14   /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-IS_INVESTIGATOR_OF-Grant_manually.csv
# 15              /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-PRESENTED-Presentation.csv
#
#                                   metadataHeader  \
# 0                                        from,to
# 1                                        from,to
# 2                                        from,to
# 3                                        from,to
# 4                                        from,to
# 5                                        from,to
# 6                                        from,to
# 7                                        from,to
# 8                                        from,to
# 9                                        from,to
# 10                           from,to,lastUpdated
# 11                                       from,to
# 12                                       from,to
# 13  from,to,isPi,isContactPi,isStudyInvestigator
# 14  from,to,isPi,isContactPi,isStudyInvestigator
# 15                                       from,to
#
#                                                                                                importHeader  \
# 0                                                        :START_ID(ResearchInitiative-ID),:END_ID(Grant-ID)
# 1                                                             :START_ID(Researcher-ID),:END_ID(Software-ID)
# 2                                                         :START_ID(Publication-ID),:END_ID(Publication-ID)
# 3                                                        :START_ID(Grant-ID),:END_ID(ResearchInitiative-ID)
# 4                                                              :START_ID(Researcher-ID),:END_ID(Dataset-ID)
# 5                                                              :START_ID(Researcher-ID),:END_ID(Dataset-ID)
# 6                                                          :START_ID(Researcher-ID),:END_ID(Publication-ID)
# 7                                                          :START_ID(Researcher-ID),:END_ID(Publication-ID)
# 8                                                              :START_ID(Presentation-ID),:END_ID(Event-ID)
# 9                                                        :START_ID(FundingOpportunity-ID),:END_ID(Grant-ID)
# 10                                        :START_ID(Researcher-ID),:END_ID(Organization-ID),lastUpdated:int
# 11                                                             :START_ID(Researcher-ID),:END_ID(Dataset-ID)
# 12                                                              :START_ID(Researcher-ID),:END_ID(Patent-ID)
# 13  :START_ID(Researcher-ID),:END_ID(Grant-ID),isPi:boolean,isContactPi:boolean,isStudyInvestigator:boolean
# 14  :START_ID(Researcher-ID),:END_ID(Grant-ID),isPi:boolean,isContactPi:boolean,isStudyInvestigator:boolean
# 15                                                        :START_ID(Researcher-ID),:END_ID(Presentation-ID)
#
#                 source              target  \
# 0   ResearchInitiative               Grant
# 1           Researcher            Software
# 2          Publication         Publication
# 3                Grant  ResearchInitiative
# 4           Researcher             Dataset
# 5           Researcher             Dataset
# 6           Researcher         Publication
# 7           Researcher         Publication
# 8         Presentation               Event
# 9   FundingOpportunity               Grant
# 10          Researcher        Organization
# 11          Researcher             Dataset
# 12          Researcher              Patent
# 13          Researcher               Grant
# 14          Researcher               Grant
# 15          Researcher        Presentation
#
#                                                                                               metadataPath  \
# 0    /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/ResearchInitiative-SUPPORTED-Grant.csv
# 1         /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-DEVELOPED-Software.csv
# 2         /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Publication-CITES-Publication.csv
# 3       /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Grant-FUNDED-ResearchInitiative.csv
# 4            /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-CREATED-Dataset.csv
# 5            /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-CREATED-Dataset.csv
# 6       /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-AUTHORED-Publication.csv
# 7       /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-AUTHORED-Publication.csv
# 8       /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Presentation-PRESENTED_AT-Event.csv
# 9     /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/FundingOpportunity-PROVIDES-Grant.csv
# 10  /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-EMPLOYED_AT-Organization.csv
# 11              /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-USED-Dataset.csv
# 12        /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-IS_INVENTOR-Patent.csv
# 13  /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-IS_INVESTIGATOR_OF-Grant.csv
# 14  /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-IS_INVESTIGATOR_OF-Grant.csv
# 15    /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-PRESENTED-Presentation.csv
#
#     match                     fullRelationship
# 0    True   ResearchInitiative-SUPPORTED-Grant
# 1    True        Researcher-DEVELOPED-Software
# 2    True        Publication-CITES-Publication
# 3    True      Grant-FUNDED-ResearchInitiative
# 4    True           Researcher-CREATED-Dataset
# 5    True           Researcher-CREATED-Dataset
# 6    True      Researcher-AUTHORED-Publication
# 7    True      Researcher-AUTHORED-Publication
# 8    True      Presentation-PRESENTED_AT-Event
# 9    True    FundingOpportunity-PROVIDES-Grant
# 10   True  Researcher-EMPLOYED_AT-Organization
# 11   True              Researcher-USED-Dataset
# 12   True        Researcher-IS_INVENTOR-Patent
# 13   True  Researcher-IS_INVESTIGATOR_OF-Grant
# 14   True  Researcher-IS_INVESTIGATOR_OF-Grant
# 15   True    Researcher-PRESENTED-Presentation

# %%
mismatched_relationships = matched_relationships[(matched_relationships["match"] == False) & (matched_relationships["dataPath"] != "")]
if mismatched_relationships.shape[0] > 0:
    print("The following relationship data files do not match the metadata specification:")
    mismatched_relationships.to_csv(os.path.join(NEO4J_IMPORT, "mismatches_r.csv"), index=False)
    
mismatched_relationships
# Out:
# Empty DataFrame
# Columns: [relationship, dataHeader, dataPath, metadataHeader, importHeader, source, target, metadataPath, match, fullRelationship]
# Index: []

# %% [markdown]
# ## Write Neo4j header files for bulk import

# %%
def save_node_header(name, import_header, NEO4J_IMPORT):
    df = pd.DataFrame([], columns=import_header.split(","))
    df.to_csv(os.path.join(NEO4J_IMPORT, "header_" + name + "_n.csv"), index=False)

# %% [markdown]
# Write node header files

# %%
matched_nodes.query("match == True", inplace=True)

# %%
out = matched_nodes.apply(lambda row: save_node_header(row["node"], row["importHeader"], NEO4J_IMPORT), axis=1)

# %% [markdown]
# Write relationship header files

# %%
def save_relationship_header(name, import_header, NEO4J_IMPORT):
    df = pd.DataFrame([], columns=import_header.split(","))
    df.to_csv(os.path.join(NEO4J_IMPORT, "header_" + name + "_r.csv"), index=False)

# %%
matched_relationships.query("match == True", inplace=True)

# %%
matched_relationships
# Out:
#           relationship                                    dataHeader  \
# 0            SUPPORTED                                       from,to
# 1            DEVELOPED                                       from,to
# 2                CITES                                       from,to
# 3               FUNDED                                       from,to
# 4              CREATED                                       from,to
# 5              CREATED                                       from,to
# 6             AUTHORED                                       from,to
# 7             AUTHORED                                       from,to
# 8         PRESENTED_AT                                       from,to
# 9             PROVIDES                                       from,to
# 10         EMPLOYED_AT                           from,to,lastUpdated
# 11                USED                                       from,to
# 12         IS_INVENTOR                                       from,to
# 13  IS_INVESTIGATOR_OF  from,to,isPi,isContactPi,isStudyInvestigator
# 14  IS_INVESTIGATOR_OF  from,to,isPi,isContactPi,isStudyInvestigator
# 15           PRESENTED                                       from,to
#
#                                                                                                         dataPath  \
# 0              /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/ResearchInitiative-SUPPORTED-Grant.csv
# 1                   /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-DEVELOPED-Software.csv
# 2                   /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Publication-CITES-Publication.csv
# 3                 /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Grant-FUNDED-ResearchInitiative.csv
# 4             /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-CREATED-Dataset_manually.csv
# 5                      /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-CREATED-Dataset.csv
# 6   /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-AUTHORED-Publication_investigators.csv
# 7           /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-AUTHORED-Publication_other.csv
# 8                 /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Presentation-PRESENTED_AT-Event.csv
# 9               /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/FundingOpportunity-PROVIDES-Grant.csv
# 10            /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-EMPLOYED_AT-Organization.csv
# 11                        /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-USED-Dataset.csv
# 12                  /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-IS_INVENTOR-Patent.csv
# 13            /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-IS_INVESTIGATOR_OF-Grant.csv
# 14   /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-IS_INVESTIGATOR_OF-Grant_manually.csv
# 15              /Users/Peter/GitRepositories/radx-kg/kg/data/relationships/Researcher-PRESENTED-Presentation.csv
#
#                                   metadataHeader  \
# 0                                        from,to
# 1                                        from,to
# 2                                        from,to
# 3                                        from,to
# 4                                        from,to
# 5                                        from,to
# 6                                        from,to
# 7                                        from,to
# 8                                        from,to
# 9                                        from,to
# 10                           from,to,lastUpdated
# 11                                       from,to
# 12                                       from,to
# 13  from,to,isPi,isContactPi,isStudyInvestigator
# 14  from,to,isPi,isContactPi,isStudyInvestigator
# 15                                       from,to
#
#                                                                                                importHeader  \
# 0                                                        :START_ID(ResearchInitiative-ID),:END_ID(Grant-ID)
# 1                                                             :START_ID(Researcher-ID),:END_ID(Software-ID)
# 2                                                         :START_ID(Publication-ID),:END_ID(Publication-ID)
# 3                                                        :START_ID(Grant-ID),:END_ID(ResearchInitiative-ID)
# 4                                                              :START_ID(Researcher-ID),:END_ID(Dataset-ID)
# 5                                                              :START_ID(Researcher-ID),:END_ID(Dataset-ID)
# 6                                                          :START_ID(Researcher-ID),:END_ID(Publication-ID)
# 7                                                          :START_ID(Researcher-ID),:END_ID(Publication-ID)
# 8                                                              :START_ID(Presentation-ID),:END_ID(Event-ID)
# 9                                                        :START_ID(FundingOpportunity-ID),:END_ID(Grant-ID)
# 10                                        :START_ID(Researcher-ID),:END_ID(Organization-ID),lastUpdated:int
# 11                                                             :START_ID(Researcher-ID),:END_ID(Dataset-ID)
# 12                                                              :START_ID(Researcher-ID),:END_ID(Patent-ID)
# 13  :START_ID(Researcher-ID),:END_ID(Grant-ID),isPi:boolean,isContactPi:boolean,isStudyInvestigator:boolean
# 14  :START_ID(Researcher-ID),:END_ID(Grant-ID),isPi:boolean,isContactPi:boolean,isStudyInvestigator:boolean
# 15                                                        :START_ID(Researcher-ID),:END_ID(Presentation-ID)
#
#                 source              target  \
# 0   ResearchInitiative               Grant
# 1           Researcher            Software
# 2          Publication         Publication
# 3                Grant  ResearchInitiative
# 4           Researcher             Dataset
# 5           Researcher             Dataset
# 6           Researcher         Publication
# 7           Researcher         Publication
# 8         Presentation               Event
# 9   FundingOpportunity               Grant
# 10          Researcher        Organization
# 11          Researcher             Dataset
# 12          Researcher              Patent
# 13          Researcher               Grant
# 14          Researcher               Grant
# 15          Researcher        Presentation
#
#                                                                                               metadataPath  \
# 0    /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/ResearchInitiative-SUPPORTED-Grant.csv
# 1         /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-DEVELOPED-Software.csv
# 2         /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Publication-CITES-Publication.csv
# 3       /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Grant-FUNDED-ResearchInitiative.csv
# 4            /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-CREATED-Dataset.csv
# 5            /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-CREATED-Dataset.csv
# 6       /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-AUTHORED-Publication.csv
# 7       /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-AUTHORED-Publication.csv
# 8       /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Presentation-PRESENTED_AT-Event.csv
# 9     /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/FundingOpportunity-PROVIDES-Grant.csv
# 10  /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-EMPLOYED_AT-Organization.csv
# 11              /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-USED-Dataset.csv
# 12        /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-IS_INVENTOR-Patent.csv
# 13  /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-IS_INVESTIGATOR_OF-Grant.csv
# 14  /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-IS_INVESTIGATOR_OF-Grant.csv
# 15    /Users/Peter/GitRepositories/radx-kg/kg/metadata/relationships/Researcher-PRESENTED-Presentation.csv
#
#     match                     fullRelationship
# 0    True   ResearchInitiative-SUPPORTED-Grant
# 1    True        Researcher-DEVELOPED-Software
# 2    True        Publication-CITES-Publication
# 3    True      Grant-FUNDED-ResearchInitiative
# 4    True           Researcher-CREATED-Dataset
# 5    True           Researcher-CREATED-Dataset
# 6    True      Researcher-AUTHORED-Publication
# 7    True      Researcher-AUTHORED-Publication
# 8    True      Presentation-PRESENTED_AT-Event
# 9    True    FundingOpportunity-PROVIDES-Grant
# 10   True  Researcher-EMPLOYED_AT-Organization
# 11   True              Researcher-USED-Dataset
# 12   True        Researcher-IS_INVENTOR-Patent
# 13   True  Researcher-IS_INVESTIGATOR_OF-Grant
# 14   True  Researcher-IS_INVESTIGATOR_OF-Grant
# 15   True    Researcher-PRESENTED-Presentation

# %%
out = matched_relationships.apply(lambda row: save_relationship_header(row["fullRelationship"], row["importHeader"], NEO4J_IMPORT), axis=1)

# %% [markdown]
# ## Create MetaNode and MetaRelationship files

# %% [markdown]
# Compile a dictionary of all node properties

# %%
property_dir = {}
for header in matched_nodes["metadataHeader"]:
    for prop in header.split(","):
        property_dir[prop] = ""

# %% [markdown]
# Create dataframe with MetaNode data

# %%
node_list = []
for node, filepath in matched_nodes[["node","metadataPath"]].itertuples(index=False):
    node_list.append(create_meta_node(node, property_dir, filepath))
    
meta_nodes = pd.DataFrame(node_list)
meta_nodes.drop_duplicates(inplace=True)
meta_nodes.to_csv(os.path.join(NEO4J_IMPORT, "MetaNode_n.csv"), index=False)

# %%
meta_nodes
# Out:
#                                                                             id  \
# 0     Unique entity identifier: ror id if available, otherwise uei id (string)
# 1                               Unique identifier for the publication (string)
# 3    Unique researcher identifier (orcid preferred or NIH profile id) (string)
# 6                                           Identifier of the patents (string)
# 7                                   Unique identifier for the dataset (string)
# 9                                Unique id of the research initiative (string)
# 10  Unique identifier of the presentation (hash of event id and name) (string)
# 11      Identifier of the software application or software repository (string)
# 12             Unique identifier of the event (date and event number) (string)
# 13   Unique identifier for the funding opportunity (Thesaurus:C20021) (string)
# 14                 Unique identifier for the grant (Thesaurus:C16644) (string)
#
#                                                                 name  \
# 0                                  Name of the organization (string)
# 1                                  Title of the publication (string)
# 3           Name of the researcher (lastname plus initials) (string)
# 6                                       Title of the patent (string)
# 7                                       Name of the dataset (string)
# 9                   Abbreviation of the research initiative (string)
# 10                                Title of the presentation (string)
# 11  Name of the software application or software repository (string)
# 12                                        Name of the event (string)
# 13                          Name of the funding opportunity (string)
# 14                                     Title of the project (string)
#
#                                  city  \
# 0   City of the organization (string)
# 1
# 3
# 6
# 7
# 9
# 10
# 11
# 12    City of event location (string)
# 13
# 14
#
#                                                state  \
# 0                 State of the organization (string)
# 1
# 3
# 6
# 7
# 9
# 10
# 11
# 12  State or province of the event location (string)
# 13
# 14
#
#                                  country  \
# 0   Country of the organization (string)
# 1
# 3
# 6
# 7
# 9
# 10
# 11
# 12    Country of event location (string)
# 13
# 14
#
#                                                                                      ror  \
# 0   Research Organization Registry id of the organization from https://ror.org/ (string)
# 1
# 3
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                                                                                                                                                        uei  \
# 0   US government-owned Unique Entity Identifier (UEI) for the organization (https://grants.nih.gov/grants/guide/notice-files/NOT-OD-21-170.html) (string)
# 1
# 3
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                                                                    duns  \
# 0   Data Universal Numbering System (DUNS) by Dun & Bradstreet (string)
# 1
# 3
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                                                                      geonames  \
# 0   Unique identifier for geolocation from https://www.geonames.org/ (string)
# 1
# 3
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                                                                          url  \
# 0   Research Organization Registry landing page of the organization (string)
# 1                                                URL of publication (string)
# 3
# 6                                             URL of patent webpage (string)
# 7                                       URL to dataset landing page (string)
# 9                            URL of the research initiative website (string)
# 10
# 11           URL of the software application or software repository (string)
# 12
# 13                           URL to funding opportunity description (string)
# 14
#
#                                 abstract                       journal  \
# 0
# 1   Abstract of the publication (string)  Name of the journal (string)
# 3
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14             Project abstract (string)
#
#                          year                                    type  \
# 0
# 1   Year of publication (int)  primary or secondary citation (string)
# 3
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                                                       doi  \
# 0
# 1   Digital Object Identifier of the publication (string)
# 3
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                                              pmId  \
# 0
# 1   PubMed identifier of the publication (string)
# 3
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                                                                    pmcId  \
# 0
# 1   PubMedCentral identifier of the publication full text entry (string)
# 3
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                                fullName            firstName  \
# 0
# 1
# 3   First middle and last name (string)  First name (string)
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                                 middleName            lastName  \
# 0
# 1
# 3   Middle name or middle initial (string)  Last name (string)
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                                                                   orcid  \
# 0
# 1
# 3   Unique reseacher identifier from ORICD (https://orcid.org) (string)
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                                                                                   profileId  \
# 0
# 1
# 3   Unique researcher identifier from NIH Reporter (https://api.reporter.nih.gov/) (string)
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                            inventors  \
# 0
# 1
# 3
# 6   Name of the inventors (string[])
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                                       filingDate  \
# 0
# 1
# 3
# 6   Date the patent application was filed (date)
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                            grantedDate                      status  \
# 0
# 1
# 3
# 6   Date the patent was granted (date)  active or pending (string)
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                                                                   applicants  \
# 0
# 1
# 3
# 6   Name of the organization(s) that filed the patent application (string[])
# 7
# 9
# 10
# 11
# 12
# 13
# 14
#
#                                       longName  \
# 0
# 1
# 3
# 6
# 7
# 9   Long name for research initiative (string)
# 10
# 11
# 12
# 13
# 14
#
#                                                     description  \
# 0
# 1
# 3
# 6
# 7
# 9               Description of the research initiative (string)
# 10
# 11  Description of the software or software repository (string)
# 12
# 13
# 14
#
#                                                                   researchInitiativeUrl  \
# 0
# 1
# 3
# 6
# 7
# 9   Description of the research initiative that funded the research initiative (string)
# 10
# 11
# 12
# 13
# 14
#
#                                websites  \
# 0
# 1
# 3
# 6
# 7
# 9   URLs of related websites (string[])
# 10
# 11
# 12
# 13
# 14
#
#                                                        presenters  \
# 0
# 1
# 3
# 6
# 7
# 9
# 10  List of presenters separated by the vertical bar "|" (string)
# 11
# 12
# 13
# 14
#
#                           presentationUrl  \
# 0
# 1
# 3
# 6
# 7
# 9
# 10  URL of the presentation link (string)
# 11
# 12
# 13
# 14
#
#                                       videoUrl  \
# 0
# 1
# 3
# 6
# 7
# 9
# 10  URL of the presentation recording (string)
# 11
# 12
# 13
# 14
#
#                                                                                                                                               eventType  \
# 0
# 1
# 3
# 6
# 7
# 9
# 10
# 11
# 12  Type of event: webinar, virtual conference, in-person conference, hybrid conference, virtual workshop, in-person workshop, hybrid workshop (string)
# 13
# 14
#
#                              eventUrl                   startDate  \
# 0
# 1
# 3
# 6
# 7
# 9
# 10
# 11
# 12  URL of the event website (string)  Start date of event (date)
# 13
# 14
#
#                      endDate                   narrative  \
# 0
# 1
# 3
# 6
# 7
# 9
# 10
# 11
# 12  End data of event (date)
# 13
# 14                            Short description (string)
#
#                                  fundingMechanism               awardCode  \
# 0
# 1
# 3
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14  The type of award (Thesaurus:C20020) (string)  Code of award (string)
#
#                                                researchInitiative  \
# 0
# 1
# 3
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14  The initiative or program associated with this grant (string)
#
#                                               subProject  \
# 0
# 1
# 3
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14  A group of grants on related research areas (string)
#
#    nodeName:ID(MetaNode-ID)
# 0              Organization
# 1               Publication
# 3                Researcher
# 6                    Patent
# 7                   Dataset
# 9        ResearchInitiative
# 10             Presentation
# 11                 Software
# 12                    Event
# 13       FundingOpportunity
# 14                    Grant

# %% [markdown]
# Compile a dictionary of all relationship properties

# %%
property_dir = {}
for header in matched_relationships["metadataHeader"]:
    for property in header.split(","):
        property_dir[property] = ""

# %% [markdown]
# Create dataframe with MetaRelationship data

# %%
relationship_list = []
for relationship, source, target, filepath in matched_relationships[["relationship", "source", "target", "metadataPath"]].itertuples(index=False):
    relationship_list.append(create_meta_relationship(relationship, source, target, property_dir, filepath))
    
meta_relationships = pd.DataFrame(relationship_list)
meta_relationships.drop_duplicates(inplace=True)
meta_relationships.to_csv(os.path.join(NEO4J_IMPORT, "MetaRelationship_r.csv"), index=False)

# %%
meta_relationships
# Out:
#                                                                          from  \
# 0                      Unique identifier for the research initiative (string)
# 1                               Unique identifier for the researcher (string)
# 2                                          DOI of citing publication (string)
# 3                 Unique identifier for the grant (Thesaurus:C16644) (string)
# 4                               Unique identifier for the researcher (string)
# 6                               Unique identifier for the researcher (string)
# 8                             Unique identifier for the presentation (string)
# 9   Unique identifier for the funding opportunity (Thesaurus:C20021) (string)
# 10                              Unique identifier for the researcher (string)
# 11                              Unique identifier for the researcher (string)
# 12                              Unique identifier for the researcher (string)
# 13                              Unique identifier for the researcher (string)
# 15                               Unique identifier of the researcher (string)
#
#                                                                                 to  \
# 0                      Unique identifier for the grant (Thesaurus:C16644) (string)
# 1   Unique identifier for the software application or software repository (string)
# 2                                                DOI of cited publication (string)
# 3                           Unique identifier for the research initiative (string)
# 4                     Unique identifier (CRUIE preferred) for the dataset (string)
# 6                                       Unique identifier for publication (string)
# 8                                         Unique identifier for the event (string)
# 9                      Unique identifier for the grant (Thesaurus:C16644) (string)
# 10        Unique entity identifier: ror id if available, otherwise uei id (string)
# 11                    Unique identifier (CRUIE preferred) for the dataset (string)
# 12                                       Unique identifier for the patent (string)
# 13               Unique identifier for the grant without prefix or suffix (string)
# 15                                  Unique identifier of the presentation (string)
#
#                                                 lastUpdated  \
# 0
# 1
# 2
# 3
# 4
# 6
# 8
# 9
# 10  NIH fiscal year this information was last updated (int)
# 11
# 12
# 13
# 15
#
#                                                   isPi  \
# 0
# 1
# 2
# 3
# 4
# 6
# 8
# 9
# 10
# 11
# 12
# 13  True if researcher is a PI for the grant (boolean)
# 15
#
#                                        isContactPi  \
# 0
# 1
# 2
# 3
# 4
# 6
# 8
# 9
# 10
# 11
# 12
# 13  True if researcher is the contact PI (boolean)
# 15
#
#                                            isStudyInvestigator  \
# 0
# 1
# 2
# 3
# 4
# 6
# 8
# 9
# 10
# 11
# 12
# 13  True if research is the dbGaP study investigator (boolean)
# 15
#
#       relationshipName source:START_ID(MetaNode-ID) target:END_ID(MetaNode-ID)
# 0            SUPPORTED           ResearchInitiative                      Grant
# 1            DEVELOPED                   Researcher                   Software
# 2                CITES                  Publication                Publication
# 3               FUNDED                        Grant         ResearchInitiative
# 4              CREATED                   Researcher                    Dataset
# 6             AUTHORED                   Researcher                Publication
# 8         PRESENTED_AT                 Presentation                      Event
# 9             PROVIDES           FundingOpportunity                      Grant
# 10         EMPLOYED_AT                   Researcher               Organization
# 11                USED                   Researcher                    Dataset
# 12         IS_INVENTOR                   Researcher                     Patent
# 13  IS_INVESTIGATOR_OF                   Researcher                      Grant
# 15           PRESENTED                   Researcher               Presentation

# %% [markdown]
# ## Create Neo4j bulk upload command line arguments
# See: https://neo4j.com/docs/operations-manual/current/tools/neo4j-admin/neo4j-admin-import/

# %%
args = ""
for node in matched_nodes["node"].unique():
    #args += f" --nodes={node}=header_{node}_n.csv,{node}*_n.csv"
    args += f" --nodes={node}=header_{node}_n.csv,{node}.*_n.csv"

# %%
args += " --nodes=MetaNode=MetaNode_n.csv"

# %%
rel_data = matched_relationships[["relationship", "fullRelationship"]].copy()
rel_data.drop_duplicates(inplace=True)
for relationship, fullRelationship in rel_data.itertuples(index=False):
    #args += f" --relationships={relationship}=header_{fullRelationship}_r.csv,{fullRelationship}*_r.csv"
    args += f" --relationships={relationship}=header_{fullRelationship}_r.csv,{fullRelationship}.*_r.csv"

# %%
args += " --relationships=MetaRelationship=MetaRelationship_r.csv"

# %%
file = open(os.path.join(NEO4J_IMPORT, "args.txt"), "w")
file.write(args)
file.close()

# %%
print(args)
# Out:
#  --nodes=Organization=header_Organization_n.csv,Organization.*_n.csv --nodes=Publication=header_Publication_n.csv,Publication.*_n.csv --nodes=Researcher=header_Researcher_n.csv,Researcher.*_n.csv --nodes=Patent=header_Patent_n.csv,Patent.*_n.csv --nodes=Dataset=header_Dataset_n.csv,Dataset.*_n.csv --nodes=ResearchInitiative=header_ResearchInitiative_n.csv,ResearchInitiative.*_n.csv --nodes=Presentation=header_Presentation_n.csv,Presentation.*_n.csv --nodes=Software=header_Software_n.csv,Software.*_n.csv --nodes=Event=header_Event_n.csv,Event.*_n.csv --nodes=FundingOpportunity=header_FundingOpportunity_n.csv,FundingOpportunity.*_n.csv --nodes=Grant=header_Grant_n.csv,Grant.*_n.csv --nodes=MetaNode=MetaNode_n.csv --relationships=SUPPORTED=header_ResearchInitiative-SUPPORTED-Grant_r.csv,ResearchInitiative-SUPPORTED-Grant.*_r.csv --relationships=DEVELOPED=header_Researcher-DEVELOPED-Software_r.csv,Researcher-DEVELOPED-Software.*_r.csv --relationships=CITES=header_Publication-CITES-Publication_r.csv,Publication-CITES-Publication.*_r.csv --relationships=FUNDED=header_Grant-FUNDED-ResearchInitiative_r.csv,Grant-FUNDED-ResearchInitiative.*_r.csv --relationships=CREATED=header_Researcher-CREATED-Dataset_r.csv,Researcher-CREATED-Dataset.*_r.csv --relationships=AUTHORED=header_Researcher-AUTHORED-Publication_r.csv,Researcher-AUTHORED-Publication.*_r.csv --relationships=PRESENTED_AT=header_Presentation-PRESENTED_AT-Event_r.csv,Presentation-PRESENTED_AT-Event.*_r.csv --relationships=PROVIDES=header_FundingOpportunity-PROVIDES-Grant_r.csv,FundingOpportunity-PROVIDES-Grant.*_r.csv --relationships=EMPLOYED_AT=header_Researcher-EMPLOYED_AT-Organization_r.csv,Researcher-EMPLOYED_AT-Organization.*_r.csv --relationships=USED=header_Researcher-USED-Dataset_r.csv,Researcher-USED-Dataset.*_r.csv --relationships=IS_INVENTOR=header_Researcher-IS_INVENTOR-Patent_r.csv,Researcher-IS_INVENTOR-Patent.*_r.csv --relationships=IS_INVESTIGATOR_OF=header_Researcher-IS_INVESTIGATOR_OF-Grant_r.csv,Researcher-IS_INVESTIGATOR_OF-Grant.*_r.csv --relationships=PRESENTED=header_Researcher-PRESENTED-Presentation_r.csv,Researcher-PRESENTED-Presentation.*_r.csv --relationships=MetaRelationship=MetaRelationship_r.csv

# %% [markdown]
# ## Create a Cypher script with default Constraints, indices, and fulltext indices

# %% [markdown]
# Create constraints for all node ids and indices and fulltext indices for all string properties

# %%
indexed_nodes = matched_nodes[["node", "index", "stringProperties"]].copy()

# %%
indices = "".join(indexed_nodes["index"].unique())

# %% [markdown]
# Create fulltext index

# %%
node_names = indexed_nodes["node"].values
node_names = list(set(node_names))
node_names = "|".join(f"{w}" for w in node_names)

# %%
property_names = indexed_nodes["stringProperties"].values
property_names = list(np.unique(np.concatenate(property_names).flat))
property_names = ",n.".join(f"{w}" for w in property_names)

# %%
fulltext_index = f"CREATE FULLTEXT INDEX fulltext FOR (n:{node_names}) ON EACH [n.{property_names}];"

# %%
indices = indices + fulltext_index
indices = indices.replace(";", ";\n")

# %%
print(indices)
# Out:
# CREATE CONSTRAINT Organization FOR (n:Organization) REQUIRE n.id IS UNIQUE;
# CREATE INDEX Organization_name FOR (n:Organization) ON (n.name);
# CREATE INDEX Organization_city FOR (n:Organization) ON (n.city);
# CREATE INDEX Organization_state FOR (n:Organization) ON (n.state);
# CREATE INDEX Organization_country FOR (n:Organization) ON (n.country);
# CREATE INDEX Organization_ror FOR (n:Organization) ON (n.ror);
# CREATE INDEX Organization_uei FOR (n:Organization) ON (n.uei);
# CREATE INDEX Organization_duns FOR (n:Organization) ON (n.duns);
# CREATE INDEX Organization_geonames FOR (n:Organization) ON (n.geonames);
# CREATE INDEX Organization_url FOR (n:Organization) ON (n.url);
# CREATE CONSTRAINT Publication FOR (n:Publication) REQUIRE n.id IS UNIQUE;
# CREATE INDEX Publication_name FOR (n:Publication) ON (n.name);
# CREATE INDEX Publication_abstract FOR (n:Publication) ON (n.abstract);
# CREATE INDEX Publication_journal FOR (n:Publication) ON (n.journal);
# CREATE INDEX Publication_type FOR (n:Publication) ON (n.type);
# CREATE INDEX Publication_doi FOR (n:Publication) ON (n.doi);
# CREATE INDEX Publication_pmId FOR (n:Publication) ON (n.pmId);
# CREATE INDEX Publication_pmcId FOR (n:Publication) ON (n.pmcId);
# CREATE INDEX Publication_url FOR (n:Publication) ON (n.url);
# CREATE CONSTRAINT Researcher FOR (n:Researcher) REQUIRE n.id IS UNIQUE;
# CREATE INDEX Researcher_name FOR (n:Researcher) ON (n.name);
# CREATE INDEX Researcher_fullName FOR (n:Researcher) ON (n.fullName);
# CREATE INDEX Researcher_firstName FOR (n:Researcher) ON (n.firstName);
# CREATE INDEX Researcher_middleName FOR (n:Researcher) ON (n.middleName);
# CREATE INDEX Researcher_lastName FOR (n:Researcher) ON (n.lastName);
# CREATE INDEX Researcher_orcid FOR (n:Researcher) ON (n.orcid);
# CREATE INDEX Researcher_profileId FOR (n:Researcher) ON (n.profileId);
# CREATE CONSTRAINT Patent FOR (n:Patent) REQUIRE n.id IS UNIQUE;
# CREATE INDEX Patent_name FOR (n:Patent) ON (n.name);
# CREATE INDEX Patent_status FOR (n:Patent) ON (n.status);
# CREATE INDEX Patent_url FOR (n:Patent) ON (n.url);
# CREATE CONSTRAINT Dataset FOR (n:Dataset) REQUIRE n.id IS UNIQUE;
# CREATE INDEX Dataset_name FOR (n:Dataset) ON (n.name);
# CREATE INDEX Dataset_url FOR (n:Dataset) ON (n.url);
# CREATE CONSTRAINT ResearchInitiative FOR (n:ResearchInitiative) REQUIRE n.id IS UNIQUE;
# CREATE INDEX ResearchInitiative_name FOR (n:ResearchInitiative) ON (n.name);
# CREATE INDEX ResearchInitiative_longName FOR (n:ResearchInitiative) ON (n.longName);
# CREATE INDEX ResearchInitiative_description FOR (n:ResearchInitiative) ON (n.description);
# CREATE INDEX ResearchInitiative_researchInitiativeUrl FOR (n:ResearchInitiative) ON (n.researchInitiativeUrl);
# CREATE INDEX ResearchInitiative_url FOR (n:ResearchInitiative) ON (n.url);
# CREATE CONSTRAINT Presentation FOR (n:Presentation) REQUIRE n.id IS UNIQUE;
# CREATE INDEX Presentation_name FOR (n:Presentation) ON (n.name);
# CREATE INDEX Presentation_presenters FOR (n:Presentation) ON (n.presenters);
# CREATE INDEX Presentation_presentationUrl FOR (n:Presentation) ON (n.presentationUrl);
# CREATE INDEX Presentation_videoUrl FOR (n:Presentation) ON (n.videoUrl);
# CREATE CONSTRAINT Software FOR (n:Software) REQUIRE n.id IS UNIQUE;
# CREATE INDEX Software_name FOR (n:Software) ON (n.name);
# CREATE INDEX Software_description FOR (n:Software) ON (n.description);
# CREATE INDEX Software_url FOR (n:Software) ON (n.url);
# CREATE CONSTRAINT Event FOR (n:Event) REQUIRE n.id IS UNIQUE;
# CREATE INDEX Event_name FOR (n:Event) ON (n.name);
# CREATE INDEX Event_eventType FOR (n:Event) ON (n.eventType);
# CREATE INDEX Event_eventUrl FOR (n:Event) ON (n.eventUrl);
# CREATE INDEX Event_city FOR (n:Event) ON (n.city);
# CREATE INDEX Event_state FOR (n:Event) ON (n.state);
# CREATE INDEX Event_country FOR (n:Event) ON (n.country);
# CREATE CONSTRAINT FundingOpportunity FOR (n:FundingOpportunity) REQUIRE n.id IS UNIQUE;
# CREATE INDEX FundingOpportunity_name FOR (n:FundingOpportunity) ON (n.name);
# CREATE INDEX FundingOpportunity_url FOR (n:FundingOpportunity) ON (n.url);
# CREATE CONSTRAINT Grant FOR (n:Grant) REQUIRE n.id IS UNIQUE;
# CREATE INDEX Grant_name FOR (n:Grant) ON (n.name);
# CREATE INDEX Grant_abstract FOR (n:Grant) ON (n.abstract);
# CREATE INDEX Grant_narrative FOR (n:Grant) ON (n.narrative);
# CREATE INDEX Grant_fundingMechanism FOR (n:Grant) ON (n.fundingMechanism);
# CREATE INDEX Grant_awardCode FOR (n:Grant) ON (n.awardCode);
# CREATE INDEX Grant_researchInitiative FOR (n:Grant) ON (n.researchInitiative);
# CREATE INDEX Grant_subProject FOR (n:Grant) ON (n.subProject);
# CREATE FULLTEXT INDEX fulltext FOR (n:Organization|ResearchInitiative|Software|Event|Publication|FundingOpportunity|Presentation|Patent|Grant|Dataset|Researcher) ON EACH [n.abstract,n.awardCode,n.city,n.country,n.description,n.doi,n.duns,n.eventType,n.eventUrl,n.firstName,n.fullName,n.fundingMechanism,n.geonames,n.journal,n.lastName,n.longName,n.middleName,n.name,n.narrative,n.orcid,n.pmId,n.pmcId,n.presentationUrl,n.presenters,n.profileId,n.researchInitiative,n.researchInitiativeUrl,n.ror,n.state,n.status,n.subProject,n.type,n.uei,n.url,n.videoUrl];

# %%
with open(os.path.join(NEO4J_IMPORT, "indices.cypher"), "w") as f:
    f.write(indices)
