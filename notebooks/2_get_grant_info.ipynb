# %% [markdown]
# # get_grant_info
# This notebook creates grant-related node and relationship files for the RADx-KG:
# * Grant.csv
# * FundingOpportunity.csv
# * FundingOpportunity-PROVIDES-Grant.csv

# %%
import os
import grant_query
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_colwidth', None)

# %%
KG_PATH = "../kg/data"
DERIVED_DATA_PATH = "../derived_data"

# %%
START_FISCAL_YEAR = 2021 # starts Oct. 1, 2020

# %%
projects = pd.read_csv(os.path.join(DERIVED_DATA_PATH, "radx-projects.csv"))
projects.query("researchInitiative == 'RADx-rad'", inplace=True)

# %%
print(f"Number of projects {projects.shape[0]}")
projects.head()
# Out:
# Number of projects 50
#    researchInitiative   dbgapAccession         projectNum coreProjectNum  \
# 0            RADx-rad  phs002744.v1.p1        U01AA029345    U01AA029345
# 12           RADx-rad  phs002778.v1.p1    1U18TR003793-01    U18TR003793
# 26           RADx-rad  phs002604.v1.p1    1U01DA053949-01    U01DA053949
# 27           RADx-rad  phs002583.v1.p1    5U01HL150852-02    U01HL150852
# 28           RADx-rad  phs002603.v1.p1  3R33HD105594-03S1    R33HD105594
#
#    projectSerialNum     studyInvestigator  \
# 0          AA029345        Khalid Salaita
# 12         TR003793         Shannon Stott
# 26         DA053949  Anne-Catrin Uhlemann
# 27         HL150852      Edward P DeMauro
# 28         HD105594      Audrey Odom-John
#
#                                            studyTitle  \
# 0   Rapid Acceleration of Diagnostics - Radical (R...
# 12  Rapid Acceleration of Diagnostics - Radical (R...
# 26  Rapid Acceleration of Diagnostics - RADICAL (R...
# 27  Rapid Acceleration of Diagnostics - Radical  (...
# 28  Rapid Acceleration of Diagnostics - Radical  (...
#
#                        subProject
# 0   Automatic Detection & Tracing
# 12                        Exosome
# 26                     Wastewater
# 27       Novel Biosensing and VOC
# 28                   PreVAIL kIds

# %%
project_num = list(projects["coreProjectNum"].unique())
print("Number of unique core project numbers:", len(project_num))
# Out:
# Number of unique core project numbers: 48

# %% [markdown]
# ### Create Grant nodes

# %%
grants = grant_query.get_projects(project_num)
grants["applId"] = grants["applId"].astype(str)
grants = grant_query.get_projects(project_num)
grants["fiscalYear"] = grants["fiscalYear"].astype(int)
# Out:
# /Users/Peter/GitRepositories/radx-kg/notebooks/grant_query.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["project_serial_num"].fillna("", inplace=True)
# /Users/Peter/GitRepositories/radx-kg/notebooks/grant_query.py:76: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["covid_response"].fillna("", inplace=True)
# /Users/Peter/GitRepositories/radx-kg/notebooks/grant_query.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["project_serial_num"].fillna("", inplace=True)
# /Users/Peter/GitRepositories/radx-kg/notebooks/grant_query.py:76: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["covid_response"].fillna("", inplace=True)

# %%
grants = grants[(grants["fiscalYear"] >= START_FISCAL_YEAR) | grants["fiscalYear"].isna()]

# %%
grants.sort_values(by="fiscalYear", inplace=True)
grants.drop_duplicates(subset=["coreProjectNum", "fiscalYear"], keep='last', inplace=True)

# %%
grants["agency"].unique()
# Out:
# array(['NIDA', 'NIAAA', 'NICHD', 'NIDCR', 'NHLBI', 'NCATS', 'NIDCD',
#        'NINR', 'NIDDK', 'NLM', 'NIMHD', 'NIEHS'], dtype=object)

# %%
print("Number of grants:", grants.shape[0])
# Out:
# Number of grants: 99

# %%
grants["fiscalYear"].value_counts()
# Out:
# fiscalYear
# 2021    47
# 2022    42
# 2023    10
# Name: count, dtype: int64

# %%
grant_nodes = grants.merge(projects[["coreProjectNum", "researchInitiative", "subProject"]], on="coreProjectNum", how="right")
print("Number of grant nodes:", grant_nodes.shape[0])
# Out:
# Number of grant nodes: 101

# %%
grant_node_map = {"coreProjectNum": "id", "projectTitle": "name", "abstract": "abstract", 
                  "narrative": "narrative", "fundingMechanism": "fundingMechanism",
                  "awardCode": "awardCode", "researchInitiative": "researchInitiative", "subProject": "subProject"}

# %%
grant_nodes = grant_nodes[grant_node_map.keys()].copy()
grant_nodes.rename(columns=grant_node_map, inplace=True)
grant_nodes.drop_duplicates(inplace=True)
grant_nodes.fillna("", inplace=True)

# %%
# Remove common headers from abstract and narrative text
grant_nodes["abstract"] = grant_nodes["abstract"].apply(grant_query.remove_prefix, prefix="project")
grant_nodes["abstract"] = grant_nodes["abstract"].apply(grant_query.remove_prefix, prefix="abstract")
grant_nodes["abstract"] = grant_nodes["abstract"].apply(grant_query.remove_prefix, prefix="summary")
grant_nodes["narrative"] = grant_nodes["narrative"].apply(grant_query.remove_prefix, prefix="project")
grant_nodes["narrative"] = grant_nodes["narrative"].apply(grant_query.remove_prefix, prefix="narrative")
grant_nodes["narrative"] = grant_nodes["narrative"].apply(grant_query.remove_prefix, prefix="public health narrative")
grant_nodes["narrative"] = grant_nodes["narrative"].apply(grant_query.remove_prefix, prefix="relevance to public health statement")

# %%
# TODO check where name of grant varies for the same grant id
grant_nodes.drop_duplicates(subset="id", inplace=True)
print(grant_nodes.shape[0])
grant_nodes
# Out:
# 48
#              id                                               name  \
# 0   U01AA029345  Rolosense: An innovative platform for automati...
# 2   U18TR003793  Microfluidic Isolation and Characterization of...
# 4   U01DA053949  Optimizing SARS-CoV-2 wastewater based surveil...
# 6   U01HL150852         Rutgers Optimizes Innovation (ROI) Program
# 8   R33HD105594             Diagnosis of MIS-C in febrile children
# 9   R01DC016112  A confectionary-based screening tool for asses...
# 10  R44DE030842  A scalable aptamer-based electrochemical biose...
# 12  R44DE030852  Designer DNA Nanostructure Based Biosensing fo...
# 14  U18TR003780  Exosome-based Non-traditional Technologies Tow...
# 16  U01DA053899  Improved scalability, sensitivity, and interpr...
# 18  U01DC019579  Longitudinal At Home Smell Testing to Detect I...
# 20  ZIAES103366  SARS-CoV-2 Diagnostic/Prognostic Sequencing Me...
# 23  R61HD105591  A data science approach to identify and manage...
# 25  U18TR003787  A Handheld Microchip for GC analysis of breath...
# 27  R42DE030829  A multimodal platform for Oral screening of CO...
# 29  U54HL119145                Boston Biomedical Innovation Center
# 31  R42DE030832  A SARS-CoV-2 Breathalyzer for Direct Virus Det...
# 32  U18TR003778  AFS/SERS Saliva-based SARS-CoV-2 Earliest Infe...
# 34  R61HD105593  AICORE-kids: Artificial Intelligence COVID-19 ...
# 36  U01LM013129  Bioinformatics Framework for Wastewater-based ...
# 38  U01HL152401  Washington Entrepreneurial Research Evaluation...
# 40  U18TR003812  COVID-19 detection through scent analysis with...
# 42  R61HD105619  COVID-19 Network of Networks Expanding Clinica...
# 44  R61HD105590  Diagnosing and predicting risk in children wit...
# 46  U01AA029348  Detection and Automatic Privacy-Protected Cont...
# 49  U01AA029328  Development of an Automated Diagnostic Platfor...
# 51  R44DE030841  Direct bioelectronic detection of SARS-CoV-2 f...
# 53  R61HD105618  Discovery and clinical validation of host  bio...
# 55  R01DK130067  Early detection, containment, and management o...
# 58  U18TR003775  Effective, Reagent-free Detection of the Odor ...
# 60  R61HD105613  Identifying biomarker signatures of prognostic...
# 62  U01HL152410   Midwest Biomedical Accelerator Consortium: MBArC
# 65  R01MD016526  Marshallese: Alternate Surveillance for COVID-...
# 68  U01AA029324  Minimal False-alarm Touch-based Detection of S...
# 70  R01NR020105  Multi-Modal Wireless COVID Monitoring & Infect...
# 73  U18TR003807  Multi-parametric Integrated Molecular Detectio...
# 75  U01AA029331  Nanobody-Based Electrochemical Biosensor for R...
# 77  U18TR003795  Portable GC detector for breath-based COVID di...
# 79  U01DC019573  Rapid olfactory tools for telemedicine-friendl...
# 80  U01DC019578  SCENTinel: A Rapid Smell Test for COVID-19 Sur...
# 82  U01DA053941  Development and Proof-of-Concept Implementatio...
# 84  R61HD105610  Severity Predictors Integrating salivary Trans...
# 86  U01AA029316  Touchscreen-compatible, real-time electrochemi...
# 88  R01DE031114  Validation of Smart Masks for Surveillance of ...
# 92  U01DA053976  Wastewater Analysis of SARS CoV-2 in Tribal Co...
# 94  U01DA053903  Wastewater Assessment for Coronavirus in Kentu...
# 96  U01DA053893                   Wastewater Detection of COVID-19
# 98  U24LM013755  RADx-Rad Discoveries & Data: Consortium Coordi...
#
#                                              abstract  \
# 0   The ultimate goal of this proposal is to devel...
# 2   Robust, efficient and reliable testing for SAR...
# 4   The novel coronavirus SARS-CoV-2 is causing si...
# 6   The Rutgers Optimizes Innovation (ROI) Program...
# 8   The recent emergence of SARS-CoV-2 and resulta...
# 9   The goals of this Emergency Competitive Revisi...
# 10  The COVID-19 pandemic is a critical global pub...
# 12  A Novel Saliva-Based Aptamer Detection Assay f...
# 14
# 16  Presently, the application of molecular techno...
# 18  Self-report of sudden loss of smell or taste s...
# 20  COVID-19 Diagnostics. Our proposed screening a...
# 23  Since the SARS-CoV-2 pandemic began, the emerg...
# 25  The COVID-19 pandemic has caused unprecedented...
# 27  The development of a rapid and reliable sensor...
# 29  A well-recognized gap exists in the path from ...
# 31  A substantial and growing body of evidence has...
# 32  This U18 application is responsive to the NIH’...
# 34  This work is directed at characterizing pediat...
# 36  Enabling access to comprehensive biomedical in...
# 38  The University of Washington and the entrepren...
# 40  Recent studies, including ours, have suggested...
# 42  The SARS-CoV-2 pandemic has manifested in chil...
# 44  In the wake of COVID-19 pandemic, Multisystem ...
# 46  The COVID-19 pandemic has rapidly spread acros...
# 49  The devastation caused by emerging pathogens w...
# 51  Direct bioelectronic detection of SARS-CoV-2 f...
# 53  Novel approaches for early and accurate diagno...
# 55  With older age and multiple comorbidities, dia...
# 58  COVID-19 presents a public health emergency: T...
# 60  In adults, SARS-CoV-2 infection exhibits a wid...
# 62  The goal of this project is to establish robus...
# 65  Marshallese Pacific Islanders bear a dispropor...
# 68  Available tools for detection of SARS-CoV-2 vi...
# 70  Multi-Modal Wireless COVID Monitoring & Infect...
# 73  The World Health Organization has recognized a...
# 75  PROJECT SUMMARY\n Coronavirus 2019 (COVID-19) ...
# 77  /Abstract: This proposal has two major goals: ...
# 79  The COVID-19 pandemic is the most devastating ...
# 80  Smell loss is a predominant symptom of COVID-1...
# 82  The University of Miami (UM), with three prima...
# 84  Children have been disproportionately less imp...
# 86  The SARS-CoV-2 coronavirus, the cause of the C...
# 88  Vulnerable populations do not just need testin...
# 92  The rapid onset of the COVID-19 pandemic left ...
# 94  Wastewater Assessment for Coronavirus in Kentu...
# 96  When faced with a pandemic such as SARS-Corona...
# 98  Preparing SARS-­CoV-­2 testing data for reuse ...
#
#                                             narrative        fundingMechanism  \
# 0   Public Health Statement/Narrative\nThe aim of ...           Non-SBIR/STTR
# 2   We will develop a SARS-CoV-2 detection assay u...  Other Research-Related
# 4   Wastewater based testing (WBT) holds great pro...           Non-SBIR/STTR
# 6   The Rutgers Optimizes Innovation (ROI) Program...           Non-SBIR/STTR
# 8   This research is highly relevant to public hea...           Non-SBIR/STTR
# 9   This research will develop a novel screening t...           Non-SBIR/STTR
# 10  Worldwide, healthcare systems are struggling t...               SBIR/STTR
# 12  Direct detection of viral pathogens is needed ...               SBIR/STTR
# 14  The urgent need to curb the spread of SARS-CoV...  Other Research-Related
# 16  The proposed research will enhance the usefuln...           Non-SBIR/STTR
# 18  Disturbances of smell and taste is the predomi...           Non-SBIR/STTR
# 20                                                        Intramural Research
# 23  The primary objective of this study is to desi...           Non-SBIR/STTR
# 25  8. Project Narrative\n This project will devel...  Other Research-Related
# 27  The development of rapid tests can play a time...               SBIR/STTR
# 29  Translation of basic observations into clinica...        Research Centers
# 31  Aerosol transmission of SARS-CoV-2 is a likely...               SBIR/STTR
# 32  This U18 application to develop exosome-based ...  Other Research-Related
# 34  We propose an artificial intelligence/machine ...           Non-SBIR/STTR
# 36  This biomedical informatics project will lever...           Non-SBIR/STTR
# 38  This proposal plans to create a hub to acceler...           Non-SBIR/STTR
# 40  Our team of engineers, clinicians, and data sc...  Other Research-Related
# 42  COVID-19, the disease caused by SARS-CoV-2, is...           Non-SBIR/STTR
# 44  As the COVID-19 pandemic evolved in early 2020...           Non-SBIR/STTR
# 46  The goal of the project is to develop a pipeli...           Non-SBIR/STTR
# 49  The proposed research aims to develop a multip...           Non-SBIR/STTR
# 51  The proposal seeks to provide a new bioelectro...               SBIR/STTR
# 53  Novel approaches to accurately diagnose acute ...           Non-SBIR/STTR
# 55  Dialysis patients are at high risk for serious...           Non-SBIR/STTR
# 58  This program addresses the critical unmet need...  Other Research-Related
# 60  SARS-CoV-2 infection has harshly impacted heal...           Non-SBIR/STTR
# 62  This proposal describes the design, fabricatio...           Non-SBIR/STTR
# 65  The Marshallese: Alternate Surveillance for CO...           Non-SBIR/STTR
# 68  Reliable real-time detection of SARS-CoV-2 vir...           Non-SBIR/STTR
# 70  Multi-Modal Wireless COVID Monitoring & Infect...           Non-SBIR/STTR
# 73  In this project, we propose to repurpose our s...  Other Research-Related
# 75  COVID-19 has afflicted millions of Americans w...           Non-SBIR/STTR
# 77  In the United States and worldwide, public hea...  Other Research-Related
# 79  Olfactory loss (anosmia or hyposmia) is the si...           Non-SBIR/STTR
# 80  As COVID-19 continues to spread in concurrence...           Non-SBIR/STTR
# 82  Through this collaborative study between the U...           Non-SBIR/STTR
# 84  This project is relevant to public health as d...           Non-SBIR/STTR
# 86  There is an urgent need for new and rapidly tr...           Non-SBIR/STTR
# 88  We propose to build a mask that changes color ...           Non-SBIR/STTR
# 92  SARS-CoV-2 wastewater-based epidemiology is pa...           Non-SBIR/STTR
# 94  The goal of this project is to develop a “next...           Non-SBIR/STTR
# 96  Testing of wastewater for genetic traces of SA...           Non-SBIR/STTR
# 98  The  RADx-­rad  Consortium  Data  and  Coordin...  Other Research-Related
#
#    awardCode researchInitiative                     subProject
# 0        U01           RADx-rad  Automatic Detection & Tracing
# 2        U18           RADx-rad                        Exosome
# 4        U01           RADx-rad                     Wastewater
# 6        U01           RADx-rad       Novel Biosensing and VOC
# 8        R33           RADx-rad                   PreVAIL kIds
# 9        R01           RADx-rad           Chemosensory Testing
# 10       R44           RADx-rad       Novel Biosensing and VOC
# 12       R44           RADx-rad       Novel Biosensing and VOC
# 14       U18           RADx-rad                        Exosome
# 16       U01           RADx-rad                     Wastewater
# 18       U01           RADx-rad           Chemosensory Testing
# 20       ZIA           RADx-rad   Diagnostic-Prognostic RNAseq
# 23       R61           RADx-rad                   PreVAIL kIds
# 25       U18           RADx-rad                          SCENT
# 27       R42           RADx-rad       Novel Biosensing and VOC
# 29       U54           RADx-rad       Novel Biosensing and VOC
# 31       R42           RADx-rad       Novel Biosensing and VOC
# 32       U18           RADx-rad                        Exosome
# 34       R61           RADx-rad                   PreVAIL kIds
# 36       U01           RADx-rad                     Wastewater
# 38       U01           RADx-rad       Novel Biosensing and VOC
# 40       U18           RADx-rad                          SCENT
# 42       R61           RADx-rad                   PreVAIL kIds
# 44       R61           RADx-rad                   PreVAIL kIds
# 46       U01           RADx-rad  Automatic Detection & Tracing
# 49       U01           RADx-rad  Automatic Detection & Tracing
# 51       R44           RADx-rad       Novel Biosensing and VOC
# 53       R61           RADx-rad                   PreVAIL kIds
# 55       R01           RADx-rad        Multimodal Surveillance
# 58       U18           RADx-rad                          SCENT
# 60       R61           RADx-rad                   PreVAIL kIds
# 62       U01           RADx-rad       Novel Biosensing and VOC
# 65       R01           RADx-rad        Multimodal Surveillance
# 68       U01           RADx-rad  Automatic Detection & Tracing
# 70       R01           RADx-rad        Multimodal Surveillance
# 73       U18           RADx-rad                        Exosome
# 75       U01           RADx-rad  Automatic Detection & Tracing
# 77       U18           RADx-rad                          SCENT
# 79       U01           RADx-rad           Chemosensory Testing
# 80       U01           RADx-rad           Chemosensory Testing
# 82       U01           RADx-rad                     Wastewater
# 84       R61           RADx-rad                   PreVAIL kIds
# 86       U01           RADx-rad  Automatic Detection & Tracing
# 88       R01           RADx-rad        Multimodal Surveillance
# 92       U01           RADx-rad                     Wastewater
# 94       U01           RADx-rad                     Wastewater
# 96       U01           RADx-rad                     Wastewater
# 98       U24           RADx-rad       Data Coordinating Center

# %%
grant_nodes.to_csv(os.path.join(KG_PATH, "nodes", "Grant.csv"), index=False)
print("Number of grants:", grant_nodes.shape[0])
grant_nodes
# Out:
# Number of grants: 48
#              id                                               name  \
# 0   U01AA029345  Rolosense: An innovative platform for automati...
# 2   U18TR003793  Microfluidic Isolation and Characterization of...
# 4   U01DA053949  Optimizing SARS-CoV-2 wastewater based surveil...
# 6   U01HL150852         Rutgers Optimizes Innovation (ROI) Program
# 8   R33HD105594             Diagnosis of MIS-C in febrile children
# 9   R01DC016112  A confectionary-based screening tool for asses...
# 10  R44DE030842  A scalable aptamer-based electrochemical biose...
# 12  R44DE030852  Designer DNA Nanostructure Based Biosensing fo...
# 14  U18TR003780  Exosome-based Non-traditional Technologies Tow...
# 16  U01DA053899  Improved scalability, sensitivity, and interpr...
# 18  U01DC019579  Longitudinal At Home Smell Testing to Detect I...
# 20  ZIAES103366  SARS-CoV-2 Diagnostic/Prognostic Sequencing Me...
# 23  R61HD105591  A data science approach to identify and manage...
# 25  U18TR003787  A Handheld Microchip for GC analysis of breath...
# 27  R42DE030829  A multimodal platform for Oral screening of CO...
# 29  U54HL119145                Boston Biomedical Innovation Center
# 31  R42DE030832  A SARS-CoV-2 Breathalyzer for Direct Virus Det...
# 32  U18TR003778  AFS/SERS Saliva-based SARS-CoV-2 Earliest Infe...
# 34  R61HD105593  AICORE-kids: Artificial Intelligence COVID-19 ...
# 36  U01LM013129  Bioinformatics Framework for Wastewater-based ...
# 38  U01HL152401  Washington Entrepreneurial Research Evaluation...
# 40  U18TR003812  COVID-19 detection through scent analysis with...
# 42  R61HD105619  COVID-19 Network of Networks Expanding Clinica...
# 44  R61HD105590  Diagnosing and predicting risk in children wit...
# 46  U01AA029348  Detection and Automatic Privacy-Protected Cont...
# 49  U01AA029328  Development of an Automated Diagnostic Platfor...
# 51  R44DE030841  Direct bioelectronic detection of SARS-CoV-2 f...
# 53  R61HD105618  Discovery and clinical validation of host  bio...
# 55  R01DK130067  Early detection, containment, and management o...
# 58  U18TR003775  Effective, Reagent-free Detection of the Odor ...
# 60  R61HD105613  Identifying biomarker signatures of prognostic...
# 62  U01HL152410   Midwest Biomedical Accelerator Consortium: MBArC
# 65  R01MD016526  Marshallese: Alternate Surveillance for COVID-...
# 68  U01AA029324  Minimal False-alarm Touch-based Detection of S...
# 70  R01NR020105  Multi-Modal Wireless COVID Monitoring & Infect...
# 73  U18TR003807  Multi-parametric Integrated Molecular Detectio...
# 75  U01AA029331  Nanobody-Based Electrochemical Biosensor for R...
# 77  U18TR003795  Portable GC detector for breath-based COVID di...
# 79  U01DC019573  Rapid olfactory tools for telemedicine-friendl...
# 80  U01DC019578  SCENTinel: A Rapid Smell Test for COVID-19 Sur...
# 82  U01DA053941  Development and Proof-of-Concept Implementatio...
# 84  R61HD105610  Severity Predictors Integrating salivary Trans...
# 86  U01AA029316  Touchscreen-compatible, real-time electrochemi...
# 88  R01DE031114  Validation of Smart Masks for Surveillance of ...
# 92  U01DA053976  Wastewater Analysis of SARS CoV-2 in Tribal Co...
# 94  U01DA053903  Wastewater Assessment for Coronavirus in Kentu...
# 96  U01DA053893                   Wastewater Detection of COVID-19
# 98  U24LM013755  RADx-Rad Discoveries & Data: Consortium Coordi...
#
#                                              abstract  \
# 0   The ultimate goal of this proposal is to devel...
# 2   Robust, efficient and reliable testing for SAR...
# 4   The novel coronavirus SARS-CoV-2 is causing si...
# 6   The Rutgers Optimizes Innovation (ROI) Program...
# 8   The recent emergence of SARS-CoV-2 and resulta...
# 9   The goals of this Emergency Competitive Revisi...
# 10  The COVID-19 pandemic is a critical global pub...
# 12  A Novel Saliva-Based Aptamer Detection Assay f...
# 14
# 16  Presently, the application of molecular techno...
# 18  Self-report of sudden loss of smell or taste s...
# 20  COVID-19 Diagnostics. Our proposed screening a...
# 23  Since the SARS-CoV-2 pandemic began, the emerg...
# 25  The COVID-19 pandemic has caused unprecedented...
# 27  The development of a rapid and reliable sensor...
# 29  A well-recognized gap exists in the path from ...
# 31  A substantial and growing body of evidence has...
# 32  This U18 application is responsive to the NIH’...
# 34  This work is directed at characterizing pediat...
# 36  Enabling access to comprehensive biomedical in...
# 38  The University of Washington and the entrepren...
# 40  Recent studies, including ours, have suggested...
# 42  The SARS-CoV-2 pandemic has manifested in chil...
# 44  In the wake of COVID-19 pandemic, Multisystem ...
# 46  The COVID-19 pandemic has rapidly spread acros...
# 49  The devastation caused by emerging pathogens w...
# 51  Direct bioelectronic detection of SARS-CoV-2 f...
# 53  Novel approaches for early and accurate diagno...
# 55  With older age and multiple comorbidities, dia...
# 58  COVID-19 presents a public health emergency: T...
# 60  In adults, SARS-CoV-2 infection exhibits a wid...
# 62  The goal of this project is to establish robus...
# 65  Marshallese Pacific Islanders bear a dispropor...
# 68  Available tools for detection of SARS-CoV-2 vi...
# 70  Multi-Modal Wireless COVID Monitoring & Infect...
# 73  The World Health Organization has recognized a...
# 75  PROJECT SUMMARY\n Coronavirus 2019 (COVID-19) ...
# 77  /Abstract: This proposal has two major goals: ...
# 79  The COVID-19 pandemic is the most devastating ...
# 80  Smell loss is a predominant symptom of COVID-1...
# 82  The University of Miami (UM), with three prima...
# 84  Children have been disproportionately less imp...
# 86  The SARS-CoV-2 coronavirus, the cause of the C...
# 88  Vulnerable populations do not just need testin...
# 92  The rapid onset of the COVID-19 pandemic left ...
# 94  Wastewater Assessment for Coronavirus in Kentu...
# 96  When faced with a pandemic such as SARS-Corona...
# 98  Preparing SARS-­CoV-­2 testing data for reuse ...
#
#                                             narrative        fundingMechanism  \
# 0   Public Health Statement/Narrative\nThe aim of ...           Non-SBIR/STTR
# 2   We will develop a SARS-CoV-2 detection assay u...  Other Research-Related
# 4   Wastewater based testing (WBT) holds great pro...           Non-SBIR/STTR
# 6   The Rutgers Optimizes Innovation (ROI) Program...           Non-SBIR/STTR
# 8   This research is highly relevant to public hea...           Non-SBIR/STTR
# 9   This research will develop a novel screening t...           Non-SBIR/STTR
# 10  Worldwide, healthcare systems are struggling t...               SBIR/STTR
# 12  Direct detection of viral pathogens is needed ...               SBIR/STTR
# 14  The urgent need to curb the spread of SARS-CoV...  Other Research-Related
# 16  The proposed research will enhance the usefuln...           Non-SBIR/STTR
# 18  Disturbances of smell and taste is the predomi...           Non-SBIR/STTR
# 20                                                        Intramural Research
# 23  The primary objective of this study is to desi...           Non-SBIR/STTR
# 25  8. Project Narrative\n This project will devel...  Other Research-Related
# 27  The development of rapid tests can play a time...               SBIR/STTR
# 29  Translation of basic observations into clinica...        Research Centers
# 31  Aerosol transmission of SARS-CoV-2 is a likely...               SBIR/STTR
# 32  This U18 application to develop exosome-based ...  Other Research-Related
# 34  We propose an artificial intelligence/machine ...           Non-SBIR/STTR
# 36  This biomedical informatics project will lever...           Non-SBIR/STTR
# 38  This proposal plans to create a hub to acceler...           Non-SBIR/STTR
# 40  Our team of engineers, clinicians, and data sc...  Other Research-Related
# 42  COVID-19, the disease caused by SARS-CoV-2, is...           Non-SBIR/STTR
# 44  As the COVID-19 pandemic evolved in early 2020...           Non-SBIR/STTR
# 46  The goal of the project is to develop a pipeli...           Non-SBIR/STTR
# 49  The proposed research aims to develop a multip...           Non-SBIR/STTR
# 51  The proposal seeks to provide a new bioelectro...               SBIR/STTR
# 53  Novel approaches to accurately diagnose acute ...           Non-SBIR/STTR
# 55  Dialysis patients are at high risk for serious...           Non-SBIR/STTR
# 58  This program addresses the critical unmet need...  Other Research-Related
# 60  SARS-CoV-2 infection has harshly impacted heal...           Non-SBIR/STTR
# 62  This proposal describes the design, fabricatio...           Non-SBIR/STTR
# 65  The Marshallese: Alternate Surveillance for CO...           Non-SBIR/STTR
# 68  Reliable real-time detection of SARS-CoV-2 vir...           Non-SBIR/STTR
# 70  Multi-Modal Wireless COVID Monitoring & Infect...           Non-SBIR/STTR
# 73  In this project, we propose to repurpose our s...  Other Research-Related
# 75  COVID-19 has afflicted millions of Americans w...           Non-SBIR/STTR
# 77  In the United States and worldwide, public hea...  Other Research-Related
# 79  Olfactory loss (anosmia or hyposmia) is the si...           Non-SBIR/STTR
# 80  As COVID-19 continues to spread in concurrence...           Non-SBIR/STTR
# 82  Through this collaborative study between the U...           Non-SBIR/STTR
# 84  This project is relevant to public health as d...           Non-SBIR/STTR
# 86  There is an urgent need for new and rapidly tr...           Non-SBIR/STTR
# 88  We propose to build a mask that changes color ...           Non-SBIR/STTR
# 92  SARS-CoV-2 wastewater-based epidemiology is pa...           Non-SBIR/STTR
# 94  The goal of this project is to develop a “next...           Non-SBIR/STTR
# 96  Testing of wastewater for genetic traces of SA...           Non-SBIR/STTR
# 98  The  RADx-­rad  Consortium  Data  and  Coordin...  Other Research-Related
#
#    awardCode researchInitiative                     subProject
# 0        U01           RADx-rad  Automatic Detection & Tracing
# 2        U18           RADx-rad                        Exosome
# 4        U01           RADx-rad                     Wastewater
# 6        U01           RADx-rad       Novel Biosensing and VOC
# 8        R33           RADx-rad                   PreVAIL kIds
# 9        R01           RADx-rad           Chemosensory Testing
# 10       R44           RADx-rad       Novel Biosensing and VOC
# 12       R44           RADx-rad       Novel Biosensing and VOC
# 14       U18           RADx-rad                        Exosome
# 16       U01           RADx-rad                     Wastewater
# 18       U01           RADx-rad           Chemosensory Testing
# 20       ZIA           RADx-rad   Diagnostic-Prognostic RNAseq
# 23       R61           RADx-rad                   PreVAIL kIds
# 25       U18           RADx-rad                          SCENT
# 27       R42           RADx-rad       Novel Biosensing and VOC
# 29       U54           RADx-rad       Novel Biosensing and VOC
# 31       R42           RADx-rad       Novel Biosensing and VOC
# 32       U18           RADx-rad                        Exosome
# 34       R61           RADx-rad                   PreVAIL kIds
# 36       U01           RADx-rad                     Wastewater
# 38       U01           RADx-rad       Novel Biosensing and VOC
# 40       U18           RADx-rad                          SCENT
# 42       R61           RADx-rad                   PreVAIL kIds
# 44       R61           RADx-rad                   PreVAIL kIds
# 46       U01           RADx-rad  Automatic Detection & Tracing
# 49       U01           RADx-rad  Automatic Detection & Tracing
# 51       R44           RADx-rad       Novel Biosensing and VOC
# 53       R61           RADx-rad                   PreVAIL kIds
# 55       R01           RADx-rad        Multimodal Surveillance
# 58       U18           RADx-rad                          SCENT
# 60       R61           RADx-rad                   PreVAIL kIds
# 62       U01           RADx-rad       Novel Biosensing and VOC
# 65       R01           RADx-rad        Multimodal Surveillance
# 68       U01           RADx-rad  Automatic Detection & Tracing
# 70       R01           RADx-rad        Multimodal Surveillance
# 73       U18           RADx-rad                        Exosome
# 75       U01           RADx-rad  Automatic Detection & Tracing
# 77       U18           RADx-rad                          SCENT
# 79       U01           RADx-rad           Chemosensory Testing
# 80       U01           RADx-rad           Chemosensory Testing
# 82       U01           RADx-rad                     Wastewater
# 84       R61           RADx-rad                   PreVAIL kIds
# 86       U01           RADx-rad  Automatic Detection & Tracing
# 88       R01           RADx-rad        Multimodal Surveillance
# 92       U01           RADx-rad                     Wastewater
# 94       U01           RADx-rad                     Wastewater
# 96       U01           RADx-rad                     Wastewater
# 98       U24           RADx-rad       Data Coordinating Center

# %%
print(f"Number of grant nodes: {grant_nodes.shape[0]}")
# Out:
# Number of grant nodes: 48

# %%
projects.head()
# Out:
#    researchInitiative   dbgapAccession         projectNum coreProjectNum  \
# 0            RADx-rad  phs002744.v1.p1        U01AA029345    U01AA029345
# 12           RADx-rad  phs002778.v1.p1    1U18TR003793-01    U18TR003793
# 26           RADx-rad  phs002604.v1.p1    1U01DA053949-01    U01DA053949
# 27           RADx-rad  phs002583.v1.p1    5U01HL150852-02    U01HL150852
# 28           RADx-rad  phs002603.v1.p1  3R33HD105594-03S1    R33HD105594
#
#    projectSerialNum     studyInvestigator  \
# 0          AA029345        Khalid Salaita
# 12         TR003793         Shannon Stott
# 26         DA053949  Anne-Catrin Uhlemann
# 27         HL150852      Edward P DeMauro
# 28         HD105594      Audrey Odom-John
#
#                                            studyTitle  \
# 0   Rapid Acceleration of Diagnostics - Radical (R...
# 12  Rapid Acceleration of Diagnostics - Radical (R...
# 26  Rapid Acceleration of Diagnostics - RADICAL (R...
# 27  Rapid Acceleration of Diagnostics - Radical  (...
# 28  Rapid Acceleration of Diagnostics - Radical  (...
#
#                        subProject
# 0   Automatic Detection & Tracing
# 12                        Exosome
# 26                     Wastewater
# 27       Novel Biosensing and VOC
# 28                   PreVAIL kIds

# %%
project_num = set(projects["projectSerialNum"].unique())
grant_num = set(grants["projectSerialNum"].unique())
print("Matching grants:", len(grant_num))
# Out:
# Matching grants: 48

# %%
missing = list(project_num - grant_num)
print("Missing grants:", len(missing))
# Out:
# Missing grants: 0

# %%
projects[projects["projectSerialNum"].isin(missing)]
# Out:
# Empty DataFrame
# Columns: [researchInitiative, dbgapAccession, projectNum, coreProjectNum, projectSerialNum, studyInvestigator, studyTitle, subProject]
# Index: []

# %% [markdown]
# ### Create FundingOpportunity-PROVIDES-Grant relationships

# %%
grant_funding_opportunities = grants[["coreProjectNum", "opportunityNumber"]].copy()
grant_funding_opportunities.dropna(inplace=True)
grant_funding_opportunities.drop_duplicates(inplace=True)

# %%
gfo_map = {"opportunityNumber": "from", "coreProjectNum": "to"}

# %%
gfo = grants[gfo_map.keys()].copy()
gfo.rename(columns=gfo_map, inplace=True)
gfo.drop_duplicates(inplace=True)
gfo = gfo[gfo["from"] != ""]
gfo
# Out:
#               from           to
# 85   RFA-OD-20-015  U01DA053949
# 84   RFA-OD-20-014  U01AA029316
# 83   RFA-OD-20-023  R61HD105590
# 82   RFA-OD-20-020  R44DE030852
# 81   RFA-OD-20-020  R44DE030842
# 79   RFA-OD-20-014  U01AA029328
# 78   RFA-OD-20-015  U01DA053899
# 76   RFA-OD-20-023  R61HD105619
# 75   RFA-OD-20-016  R01DE031114
# 74   RFA-OD-20-014  U01AA029348
# 73   RFA-OD-20-014  U01AA029331
# 72   RFA-HL-13-008  U54HL119145
# 71   RFA-OD-20-018  U18TR003778
# 70   RFA-OD-20-021  R42DE030832
# 69   RFA-OD-20-018  U18TR003807
# 68   RFA-OD-20-017  U18TR003812
# 67   RFA-OD-20-022  U01DC019573
# 66   RFA-OD-20-018  U18TR003793
# 65   RFA-OD-20-016  R01NR020105
# 64   RFA-OD-20-017  U18TR003787
# 88   RFA-OD-20-023  R61HD105591
# 89   RFA-OD-20-016  R01DK130067
# 87   RFA-OD-19-014  U01HL152401
# 91   RFA-OD-20-017  U18TR003795
# 113      PA-20-272  U01HL152410
# 112  RFA-OD-20-022  U01DC019579
# 111  RFA-OD-20-019  U24LM013755
# 110  RFA-OD-20-023  R61HD105610
# 109  RFA-OD-20-016  R01MD016526
# 108  RFA-OD-20-018  U18TR003780
# 107  RFA-OD-20-023  R61HD105618
# 106      PA-18-484  U01LM013129
# 90   RFA-OD-20-015  U01DA053893
# 104  RFA-OD-20-014  U01AA029345
# 102  RFA-OD-20-022  U01DC019578
# 92   RFA-OD-20-020  R44DE030841
# 93   RFA-OD-20-015  U01DA053976
# 103  RFA-OD-20-015  U01DA053941
# 95   RFA-OD-20-014  U01AA029324
# 96   RFA-OD-20-023  R61HD105593
# 98   RFA-OD-19-014  U01HL150852
# 99   RFA-OD-20-017  U18TR003775
# 100  RFA-OD-20-023  R61HD105613
# 101  RFA-OD-20-021  R42DE030829
# 97   RFA-OD-20-015  U01DA053903
# 116      PA-20-135  R01DC016112
# 62       PA-20-272  R42DE030829
# 55       PA-20-272  U01AA029331
# 54       PA-20-272  R44DE030852
# 53       PA-20-272  R61HD105590
# 51   RFA-OD-19-014  U01HL152410
# 10   RFA-OD-20-023  R33HD105594
# 8        PA-21-268  U01AA029348

# %%
gfo.to_csv(os.path.join(KG_PATH, "relationships", "FundingOpportunity-PROVIDES-Grant.csv"), index=False)
print("Number of funding opportunities:", gfo.shape[0])
gfo.head()
# Out:
# Number of funding opportunities: 53
#              from           to
# 85  RFA-OD-20-015  U01DA053949
# 84  RFA-OD-20-014  U01AA029316
# 83  RFA-OD-20-023  R61HD105590
# 82  RFA-OD-20-020  R44DE030852
# 81  RFA-OD-20-020  R44DE030842

# %%
funding_opportunities = gfo["from"].unique().tolist()

# %%
fo_details = grant_query.search_funding_opportunities(funding_opportunities)

# %%
fo_details.head()
# Out:
#        id         number                                              title  \
# 0  328588  RFA-OD-20-015  Emergency Awards: RADx-rad Wastewater Detectio...
# 1  328587  RFA-OD-20-014  Emergency Awards: Automatic Detection and Trac...
# 2  328593  RFA-OD-20-023  Emergency Awards: RADx-rad Predicting Viral-As...
# 3  328569  RFA-OD-20-020  Emergency Awards RADx-RAD: Novel Biosensing fo...
# 4  328567  RFA-OD-20-016  Emergency Awards: RADx-RAD Multimodal COVID-19...
#
#   agencyCode                         agency    openDate   closeDate oppStatus  \
# 0  HHS-NIH11  National Institutes of Health  08/06/2020  09/15/2020  archived
# 1  HHS-NIH11  National Institutes of Health  08/06/2020  09/15/2020  archived
# 2  HHS-NIH11  National Institutes of Health  08/06/2020  09/30/2020  archived
# 3  HHS-NIH11  National Institutes of Health  08/06/2020  09/18/2020  archived
# 4  HHS-NIH11  National Institutes of Health  08/06/2020  09/30/2020  archived
#
#     docType                                           cfdaList
# 0  synopsis           [93.879, 93.113, 93.310, 93.859, 93.279]
# 1  synopsis  [93.393, 93.213, 93.273, 93.396, 93.233, 93.83...
# 2  synopsis  [93.837, 93.233, 93.307, 93.855, 93.989, 93.84...
# 3  synopsis  [93.837, 93.286, 93.307, 93.879, 93.350, 93.86...
# 4  synopsis  [93.361, 93.121, 93.307, 93.859, 93.310, 93.84...

# %% [markdown]
# ### Create FundingOpportunity Nodes

# %%
fo_map = {"number": "id", "title": "name"}
fo = fo_details[fo_map.keys()].copy()
fo.rename(columns=fo_map, inplace=True)
fo.drop_duplicates(inplace=True)

# %%
fo["url"] = fo["id"].apply(grant_query.add_funding_opportunity_url)

# %%
fo.to_csv(os.path.join(KG_PATH, "nodes", "FundingOpportunity.csv"), index=False)
print("Number of funding opportunities:", fo.shape[0])
fo
# Out:
# Number of funding opportunities: 16
#                id                                               name  \
# 0   RFA-OD-20-015  Emergency Awards: RADx-rad Wastewater Detectio...
# 1   RFA-OD-20-014  Emergency Awards: Automatic Detection and Trac...
# 2   RFA-OD-20-023  Emergency Awards: RADx-rad Predicting Viral-As...
# 3   RFA-OD-20-020  Emergency Awards RADx-RAD: Novel Biosensing fo...
# 4   RFA-OD-20-016  Emergency Awards: RADx-RAD Multimodal COVID-19...
# 5   RFA-HL-13-008  The NIH Centers for Accelerated Innovations (U54)
# 6   RFA-OD-20-018  Emergency Awards: Exosome-based Non-traditiona...
# 7   RFA-OD-20-021  Emergency Awards RADx-RAD: Novel Biosensing fo...
# 8   RFA-OD-20-017  Emergency Awards RADx-RAD: Screening for COVID...
# 9   RFA-OD-20-022  Emergency Awards: Chemosensory Testing as a CO...
# 10  RFA-OD-19-014  NIH Research Evaluation and Commercialization ...
# 11      PA-20-272  Administrative Supplements to Existing NIH Gra...
# 12  RFA-OD-20-019  Emergency Awards: RADx-rad Data Coordination C...
# 13      PA-18-484  NIH Research Project Grant (Parent R01 Clinica...
# 14      PA-20-135  Emergency Competitive Revision to Existing NIH...
# 15      PA-21-268  Change of Recipient Organization (Type 7 Paren...
#
#                                                   url
# 0   https://grants.nih.gov/grants/guide/rfa-files/...
# 1   https://grants.nih.gov/grants/guide/rfa-files/...
# 2   https://grants.nih.gov/grants/guide/rfa-files/...
# 3   https://grants.nih.gov/grants/guide/rfa-files/...
# 4   https://grants.nih.gov/grants/guide/rfa-files/...
# 5   https://grants.nih.gov/grants/guide/rfa-files/...
# 6   https://grants.nih.gov/grants/guide/rfa-files/...
# 7   https://grants.nih.gov/grants/guide/rfa-files/...
# 8   https://grants.nih.gov/grants/guide/rfa-files/...
# 9   https://grants.nih.gov/grants/guide/rfa-files/...
# 10  https://grants.nih.gov/grants/guide/rfa-files/...
# 11  https://grants.nih.gov/grants/guide/pa-files/P...
# 12  https://grants.nih.gov/grants/guide/rfa-files/...
# 13  https://grants.nih.gov/grants/guide/pa-files/P...
# 14  https://grants.nih.gov/grants/guide/pa-files/P...
# 15  https://grants.nih.gov/grants/guide/pa-files/P...
