# %%
import pandas as pd
import grant_query

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
investigators = ["Hadi Shafiee", "Selim Unlu", "Timothy Gordon", "Devin MacKenzie", "Jie Huang", "James W Keck", "Edward DeMauro"]

# %%
#data, n = grant_query.search_principal_investigators_by_name(investigators, 500, 0)

# %%
df = grant_query.get_principal_investigators_by_name(investigators)

# %%
df
# Out:
#    profileId coreProjectNum projectSerialNum isContactPi fiscalYear  \
# 0   11198751    R01EB033866         EB033866        True       2023
# 1   11198751    R01AI138800         AI138800        True       2023
# 2   11198751    R33AI140489         AI140489        True       2023
# 3   11198751    R01AI138800         AI138800        True       2023
# 4   11198751    R33AI140489         AI140489        True       2022
# 5   11198751    R01EB033866         EB033866        True       2022
# 6   11198751    R01AI138800         AI138800        True       2022
# 7   11198751    R01AI138800         AI138800        True       2021
# 8   78269444    R44HD099040         HD099040        True       2021
# 9   11198751    R44HD099040         HD099040       False       2021
# 10  11198751    R61AI140489         AI140489        True       2021
# 11  11198751    R44HD099040         HD099040       False       2020
# 12  16447617    R44HD099040         HD099040        True       2020
# ...
