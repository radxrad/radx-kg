# %% [markdown]
# # RADx Reporter
# This notebook reports studies submitted by the COVID Rapid Acceleration of Diagnostics [RADx Initiative](https://www.nih.gov/research-training/medical-research-initiatives/radx) to the database of Genotypes and Phenotypes [dbGaP](https://www.ncbi.nlm.nih.gov/gap/) and provides a list of data access requests for the following projects:
#
# - [RADx Radical (RADx-rad)](https://www.nih.gov/research-training/medical-research-initiatives/radx/radx-programs#radx-rad)
# - [RADx Digital Health Technologies (RADx-DHT)](https://www.nih.gov/news-events/news-releases/nih-awards-contracts-develop-innovative-digital-health-technologies-covid-19)
# - [RADx Tech (RADx-TECH)](https://www.nih.gov/research-training/medical-research-initiatives/radx/radx-programs#radx-tech)
# - [RADx Underserved Populations (RADx-UP)](https://www.nih.gov/research-training/medical-research-initiatives/radx/radx-programs#radx-up)
#
#
#
# For a selected RADx project, it retrieves the studies related to the project and the data access requests. Access requests used to test the RADx Data Hub functionality are excluded by default, but can be optionally included.
#
# The number of access requests per study is a measure of data reuse. In addition, this notebook queries [Europe PMC](https://europepmc.org/) for publications and preprints that cite or mention dbGaP accession numbers or the RADx project name.
#
# Created: 2023-03-09
#
# Author : Peter W. Rose (pwrose@ucsd.edu)

# %%
#@title Select a RADx project and then select **Run All** from the **Runtime** menu { run: "auto", vertical-output: true, form-width: "50%", display-mode: "form" }
#@markdown ### Select a RADx project
project = 'RADx-rad' #@param ["RADx-rad","RADx-DHT","RADx-TECH","RADx-UP"]
print(f"Project: {project}")

testers = ["Rose, Peter ", "Ciofani, Danielle ", "Krishnamurthy, Ashok ", "Claypool, Kajal ", "Davis-Dusenbery, Brandi "]
#@markdown ### Exclude test requests
exclude_tests = True #@param {type:"boolean"}
print(f"Exclude test requests: {exclude_tests}")
# Out:
# Project: RADx-rad
# Exclude test requests: True

# %%
# %%capture
#@title Installing software on Google Colab
![ ! -f "installed" ] && pip -q install selenium
![ ! -f "installed" ] && apt-get update
![ ! -f "installed" ] && apt-get install firefox && touch installed

# %%
#@title Importing packages
import os
import shutil
import glob
import time
from tqdm import tqdm
from urllib.request import urlopen
import json
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options
from google.colab import data_table

# %%
#@title Running query
TMP_DIR = "/tmp"
filepath = os.path.join(TMP_DIR, "studies.csv")

def driversetup(download_dir):
    options = Options()
    #run Selenium in headless mode
    options.add_argument("--headless")
    options.add_argument("--no-sandbox")
    # https://stackoverflow.com/questions/60170311/how-to-switch-download-directory-using-selenium-firefox-python
    # 0: download to the desktop, 1 download to the default "Downloads" directory, 2 use specified directory
    options.set_preference("browser.download.folderList", 2)
    options.set_preference("browser.download.manager.showWhenStarting", False)
    options.set_preference("browser.download.dir", download_dir)
    options.set_preference("browser.helperApps.neverAsk.saveToDisk", "text/csv")
    
    # https://stackoverflow.com/questions/42204897/how-to-set-up-a-selenium-python-environment-for-firefox
    driver = webdriver.Firefox(options=options)
    driver.implicitly_wait(5)

    return driver

def download_dbgap_studies(query, filepath):
    # clean up any previously downloaded csv files
    files = glob.glob(os.path.join(TMP_DIR, "*.csv"))
    for file in files:
        os.remove(file)
    
    # download csv file
    driver = driversetup(TMP_DIR)
    # for an exact match, put query term in to quotes
    query = '"' + project + '"'
    driver.get(f"https://www.ncbi.nlm.nih.gov/gap/advanced_search/?TERM={query}")
    time.sleep(3)
    #print("Running: ", driver.title)
    button = driver.find_element(By.CLASS_NAME, "svr_container")
    time.sleep(3)
    button.click()
    # wait until download is completed
    for step in tqdm(range(15)):
        time.sleep(1)
    #time.sleep(15)
    driver.close()
                  
    # move downloaded csv file to a standard location
    move_studies_file(filepath)
    
def move_studies_file(filepath):
    """ Move downloaded file to a specified standard location"""
    # the file name of the downloaded csv file is unknown in advance,
    # but there should be only one csv file.
    files = glob.glob(os.path.join(TMP_DIR, "*.csv"))
    if len(files) == 1:
        shutil.move(files[0], filepath)
    else:
        print("query error")
        
filepath = "studies.csv"
download_dbgap_studies(project, filepath)

studies = pd.read_csv(filepath, usecols=["accession", "name", "description", "Study Design", "Study Consent",])
# post filter hits by name field to avoid false matches
studies = studies[studies["name"].str.contains(project, case=False)]
# Out:
# 100%|██████████| 15/15 [00:15<00:00,  1.00s/it]

# %%
#@title Table of studies
print(f"Number of studies for {project}:", studies.shape[0])
if studies.shape[0] > 0:
    display(data_table.DataTable(studies, include_index=False, num_rows_per_page=10))
# Out:
# Number of studies for RADx-rad: 48
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>accession</th>
#       <th>name</th>
#       <th>description</th>
#       <th>Study Design</th>
#       <th>Study Consent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>phs002585.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>This work is directed at characterizing pediat...</td>
#       <td>Case Set</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>phs002782.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>Infectious disease outbreaks like Coronavirus ...</td>
#       <td>Case Set</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>phs002679.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>When faced with a pandemic such as SARS-Corona...</td>
#       <td>Collection</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>phs002525.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>The University of Miami (UM), with three prima...</td>
#       <td>Case Set</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>phs002600.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>The data herein combines GC-MS and GC-DMS anal...</td>
#       <td>Collection</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>phs002603.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>The recent emergence of SARS-CoV2 and resultan...</td>
#       <td>Prospective Longitudinal Cohort</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>phs002685.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>Automated, rapid diagnostics with little sampl...</td>
#       <td>Case Set</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>phs002583.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>We propose to develop a novel testing platform...</td>
#       <td>Collection</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>phs002604.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>Wastewater based testing (WBT) holds great pro...</td>
#       <td>Prospective Longitudinal Cohort</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>phs002524.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>Vulnerable populations do not just need testin...</td>
#       <td>Collection</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>phs002527.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>COVID-19 is expected to become one of the larg...</td>
#       <td>Collection</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>phs002570.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>This project will develop a multiplexed sensor...</td>
#       <td>Methods</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>phs002572.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>A substantial and growing body of evidence has...</td>
#       <td>Methods</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>phs002699.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>Smell loss is a predominant symptom of COVID-1...</td>
#       <td>Cross-Sectional</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>phs002542.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>Developing next generation technology to simpl...</td>
#       <td>Case Set</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>phs002551.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>Marshallese Pacific Islanders bear a dispropor...</td>
#       <td>Collection</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>phs002565.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>We are developing an electrochemical assay for...</td>
#       <td>Methods</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>phs002689.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>The pandemic caused by COVID-19 has been assoc...</td>
#       <td>Case Set</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>phs002523.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>We plan to extend and improve our COH/PHD syst...</td>
#       <td>Collection</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>phs002631.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>The COVID-19 pandemic is the most devastating ...</td>
#       <td>Collection</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>phs002544.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>This U18 application is responsive to the NIH'...</td>
#       <td>Methods</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>phs002573.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>The goal of the project is to develop a pipeli...</td>
#       <td>Case-Control</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>phs002700.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>Coronavirus 2019 (COVID-19) has afflicted 6.2 ...</td>
#       <td>Methods</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>phs002747.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>Recent studies, including ours, have suggested...</td>
#       <td>Methods</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>phs002778.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>Robust, efficient, and reliable testing for SA...</td>
#       <td>Case-Control</td>
#       <td>HMB --- Health/medical/biomedical</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>phs002964.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>Self-report of sudden loss of smell or taste s...</td>
#       <td>Prospective Longitudinal Cohort</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>phs002553.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>As the COVID-19 pandemic evolved in early 2020...</td>
#       <td>Collection</td>
#       <td>GRU --- General research use</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>phs002561.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#       <td>A rapid, sensitive, low-cost diagnostic device...</td>
#       <td>Case Set</td>
#       <td>GRU --- Gen

# %%
#@title Summary of data access requests
def get_download_url(accession):
    return "https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/GetAuthorizedRequestDownload.cgi?study_id=" + accession

def get_authorized_requests(studies):
    authorized_requests = pd.DataFrame()

    for _, row in tqdm(studies.iterrows(), total=studies.shape[0]):
        try:
            df = pd.read_csv(get_download_url(row["accession"]), 
                             usecols=["Requestor", "Affiliation", "Project", "Date of approval", "Request status", 
                                      "Public Research Use Statement", "Technical Research Use Statement"],
                            sep="\t")
            df["accession"] = row["accession"]
            df["name"] = row["name"]
            authorized_requests = pd.concat([authorized_requests, df], ignore_index=True)
        except:
            print(f"Skipping: {row['accession']} - no data access through dbGaP.")
                                        
    return authorized_requests

requests = get_authorized_requests(studies)

# exclude test requests
n_excluded = 0
if exclude_tests:
    n_excluded = requests.shape[0]
    requests = requests[~requests["Requestor"].isin(testers)]
    n_excluded = n_excluded - requests.shape[0]


# group requests to create a summary view
if requests.shape[0] > 0:
    summary = requests.groupby(["Requestor", "Affiliation", "Project", "Date of approval", "Request status",
                                "Public Research Use Statement", "Technical Research Use Statement"], 
                                as_index=False)["accession"].agg(', '.join)

    summary["Number of requests"] = summary["accession"].str.count(",") + 1

# show results
print()
print()
if exclude_tests:
        print(f"{n_excluded} test requests have been excluded!")
        
print("Number of data access requests :", requests.shape[0])

if requests.shape[0] > 0:
    print("Number of unique requestors    :", len(requests["Requestor"].unique()))
    print("Number of unique studies       :", len(requests["accession"].unique()))
    display(data_table.DataTable(summary, include_index=False, num_rows_per_page=10))
# Out:
# 100%|██████████| 48/48 [00:25<00:00,  1.86it/s]
# 49 test requests have been excluded!
# Number of data access requests : 3
# Number of unique requestors    : 2
# Number of unique studies       : 3
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Requestor</th>
#       <th>Affiliation</th>
#       <th>Project</th>
#       <th>Date of approval</th>
#       <th>Request status</th>
#       <th>Public Research Use Statement</th>
#       <th>Technical Research Use Statement</th>
#       <th>accession</th>
#       <th>Number of requests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Anwar, Mohd Mozharul</td>
#       <td>NIH</td>
#       <td>Exploration of Wearable Device Data for COVID-19</td>
#       <td>Mar27, 2023</td>
#       <td>approved</td>
#       <td>Wearable devices collect various physiological...</td>
#       <td>The objective of the proposed research is to e...</td>
#       <td>phs002523.v1.p1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Miguez, Maria-Jose</td>
#       <td>FLORIDA INTERNATIONAL UNIVERSITY</td>
#       <td>System analysis for COVID humoral response</td>
#       <td>Feb10, 2023</td>
#       <td>approved</td>
#       <td>Multisystem inflammatory syndrome in children ...</td>
#       <td>Multisystem inflammatory syndrome in children ...</td>
#       <td>phs002781.v1.p1, phs002945.v1.p1</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#@title Detailed table of data access requests
if exclude_tests:
    print(f"{n_excluded} test requests have been excluded!")

print("Number of data access requests :", requests.shape[0])

if requests.shape[0] > 0:
    print("Number of unique requestors    :", len(requests["Requestor"].unique()))
    print("Number of unique studies       :", len(requests["accession"].unique()))
    display(data_table.DataTable(requests, include_index=False, num_rows_per_page=10))
# Out:
# 49 test requests have been excluded!
# Number of data access requests : 3
# Number of unique requestors    : 2
# Number of unique studies       : 3
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Requestor</th>
#       <th>Affiliation</th>
#       <th>Project</th>
#       <th>Date of approval</th>
#       <th>Request status</th>
#       <th>Public Research Use Statement</th>
#       <th>Technical Research Use Statement</th>
#       <th>accession</th>
#       <th>name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>19</th>
#       <td>Anwar, Mohd Mozharul</td>
#       <td>NIH</td>
#       <td>Exploration of Wearable Device Data for COVID-19</td>
#       <td>Mar27, 2023</td>
#       <td>approved</td>
#       <td>Wearable devices collect various physiological...</td>
#       <td>The objective of the proposed research is to e...</td>
#       <td>phs002523.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>Miguez, Maria-Jose</td>
#       <td>FLORIDA INTERNATIONAL UNIVERSITY</td>
#       <td>System analysis for COVID humoral response</td>
#       <td>Feb10, 2023</td>
#       <td>approved</td>
#       <td>Multisystem inflammatory syndrome in children ...</td>
#       <td>Multisystem inflammatory syndrome in children ...</td>
#       <td>phs002781.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>Miguez, Maria-Jose</td>
#       <td>FLORIDA INTERNATIONAL UNIVERSITY</td>
#       <td>System analysis for COVID humoral response</td>
#       <td>Feb10, 2023</td>
#       <td>approved</td>
#       <td>Multisystem inflammatory syndrome in children ...</td>
#       <td>Multisystem inflammatory syndrome in children ...</td>
#       <td>phs002945.v1.p1</td>
#       <td>Rapid Acceleration of Diagnostics - Radical (R...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#@title Publications that cite or mention dbGaP accession numbers (source: Europe PMC)
studies["dbgap"] = studies["accession"].apply(lambda s: s.split(".")[0])
# get list of publications from Europe PMC
dbgap_pub = pd.read_csv("ftp://ftp.ebi.ac.uk/pub/databases/pmc/TextMinedTerms/dbgap.csv")
pubs = studies.merge(dbgap_pub, on="dbgap")
pubs.fillna("", inplace=True)
print("Number of publications:", pubs.shape[0])
display(data_table.DataTable(pubs, include_index=False, num_rows_per_page=10))
# Out:
# Number of publications: 0
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>accession</th>
#       <th>name</th>
#       <th>description</th>
#       <th>Study Design</th>
#       <th>Study Consent</th>
#       <th>dbgap</th>
#       <th>PMCID</th>
#       <th>EXTID</th>
#       <th>SOURCE</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
#@title Publications and preprints that mention  RADx project (source: Europe PMC)
url = f"https://www.ebi.ac.uk/europepmc/webservices/rest/search?query=%22{project}%22%20AND%20(FIRST_PDATE:2020-06-01)%20AND%20sort_date:y&resultType=core&pageSize=1000&format=json&cursorMark=*"

response = urlopen(url)
data_json = json.loads(response.read())

df = pd.json_normalize(data_json["resultList"]["result"])
df.fillna("", inplace=True)

df.rename(columns={"fullTextIdList.fullTextId": "fullTextId"}, inplace=True)

if df.shape[0] > 0:
    df = df[["pmid", "fullTextId", "title", "authorString", "pubYear", "affiliation", "citedByCount"]]

    print(f"Number of publications and preprints containing the keyword: {project}: {df.shape[0]}")
    print(f"Number of citations: {df['citedByCount'].sum()}")
    display(data_table.DataTable(df, include_index=False, num_rows_per_page=10))
else:
    print(f"Number of publications and preprints containing the keyword: {project}: 0")
# Out:
# Number of publications and preprints containing the keyword: RADx-rad: 25
# Number of citations: 225
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pmid</th>
#       <th>fullTextId</th>
#       <th>title</th>
#       <th>authorString</th>
#       <th>pubYear</th>
#       <th>affiliation</th>
#       <th>citedByCount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>36965380</td>
#       <td>[PMC10027305]</td>
#       <td>Data-driven design of a multiplexed, peptide-s...</td>
#       <td>Nakano-Baker O, Fong H, Shukla S, Lee RV, Cai ...</td>
#       <td>2023</td>
#       <td>University of Washington Dept. of Materials Sc...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>36933724</td>
#       <td>[PMC10017378]</td>
#       <td>Wastewater surveillance uncovers regional dive...</td>
#       <td>Fontenele RS, Yang Y, Driver EM, Magge A, Krab...</td>
#       <td>2023</td>
#       <td>National Library of Medicine, National Institu...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>36623667</td>
#       <td>[PMC9817413]</td>
#       <td>Degradation rates influence the ability of com...</td>
#       <td>Babler KM, Sharkey ME, Abelson S, Amirali A, B...</td>
#       <td>2023</td>
#       <td>Department of Chemical, Environmental, and Mat...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>36482179</td>
#       <td>[PMC9731983]</td>
#       <td>Predominant SARS-CoV-2 variant impacts accurac...</td>
#       <td>McCartney MM, Borras E, Rojas DE, Hicks TL, Ha...</td>
#       <td>2022</td>
#       <td>Mechanical and Aerospace Engineering, UC Davis...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>36493788</td>
#       <td>[PMC9725778]</td>
#       <td>Leveraging an established neighbourhood-level,...</td>
#       <td>Bowes DA, Driver EM, Kraberger S, Fontenele RS...</td>
#       <td>2023</td>
#       <td>The Biodesign Institute Center for Environment...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>36354449</td>
#       <td>[PMC9688365]</td>
#       <td>An Experimental Framework for Developing Point...</td>
#       <td>Ullah SF, Moreira G, Datta SPA, McLamore E, Va...</td>
#       <td>2022</td>
#       <td>Division of Glycoscience, Department of Chemis...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>[PPR541952]</td>
#       <td>Portable Breath-Based Volatile Organic Compoun...</td>
#       <td>Sharma R, Zang W, Tabartehfarahani A, Lam A, H...</td>
#       <td>2022</td>
#       <td></td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td></td>
#       <td>[PPR535354]</td>
#       <td>Data-Driven Design of Protein-Derived Peptide ...</td>
#       <td>Nakano-Baker O, Fong H, Shukla S, Lee R, Cai L...</td>
#       <td>2022</td>
#       <td></td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>35992634</td>
#       <td>[PMC9386735]</td>
#       <td>Development of a Biosensor Based on Angiotensi...</td>
#       <td>Moreira G, Casso-Hartmann L, Datta SPA, Dean D...</td>
#       <td>2022</td>
#       <td>Department of Environmental Engineering and Ea...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td></td>
#       <td>[PPR511405]</td>
#       <td>Outbreak.info Research Library: A standardized...</td>
#       <td>Hughes L, Tsueng G, Mullen J, Alkuzweny M, Can...</td>
#       <td>2022</td>
#       <td></td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>35632824</td>
#       <td>[PMC9148162]</td>
#       <td>Pivoting Novel Exosome-Based Technologies for ...</td>
#       <td>Happel C, Peñalber-Johnstone C, Tagle DA.</td>
#       <td>2022</td>
#       <td>National Center for Advancing Translational Sc...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>35093995</td>
#       <td>[PMC8919949]</td>
#       <td>Distinguishing Multisystem Inflammatory Syndro...</td>
#       <td>Godfred-Cato S, Abrams JY, Balachandran N, Jag...</td>
#       <td>2022</td>
#       <td>CDC COVID-19 Response Team, Atlanta, GA.</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td></td>
#       <td>[PPR471521]</td>
#       <td>Proof-of-concept: SCENTinel 1.1 rapidly discri...</td>
#       <td>Hunter SR, Hannum ME, Pellegrino R, O’Leary MA...</td>
#       <td>2022</td>
#       <td></td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td></td>
#       <td>[PPR445454]</td>
#       <td>Outbreak.info Research Library: A standardized...</td>
#       <td>Tsueng G, Mullen JL, Alkuzweny M, Cano M, Rush...</td>
#       <td>2022</td>
#       <td></td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>34893640</td>
#       <td>[PMC8664884]</td>
#       <td>Proteomic profiling of MIS-C patients indicate...</td>
#       <td>Diorio C, Shraim R, Vella LA, Giles JR, Baxter...</td>
#       <td>2021</td>
#       <td>Division of Oncology, Department of Pediatrics...</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>34778896</td>
#       <td>[PMC8860149]</td>
#       <td>Point-of-care diagnostics: recent developments...</td>
#       <td>Harpaldas H, Arumugam S, Campillo Rodriguez C,...</td>
#       <td>2021</td>
#       <td>Department of Biomedical Engineering, Columbia...</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td></td>
#       <td>[PPR377134]</td>
#       <td>Unrestricted Online Sharing of High-frequency,...</td>
#       <td>Bowes DA, Driver EM, Kraberger S, Fontenele RS...</td>
#       <td>2021</td>
#       <td></td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>34611607</td>
#       <td>[PMC8486427]</td>
#       <td>Biomedical Research COVID-19 Impact Assessment...</td>
#       <td>Cook NL, Lauer MS.</td>
#       <td>2021</td>
#       <td>Patient-Centered Outcomes Research Institute.</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>34514084</td>
#       <td>[PMC8420437]</td>
#       <td>SARS-CoV-2 RNA Detection by a Cellphone-Based ...</td>
#       <td>Silva FSR, Erdogmus E, Shokr A, Kandula H, Thi...</td>
#       <td>2021</td>
#       <td>Division of Engineering in Medicine Department...</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td></td>
#       <td>[PPR314466]</td>
#       <td>Proteomic Profiling of MIS-C Patients Reveals ...</td>
#       <td>Diorio C, Shraim R, Vella LA, Giles JR, Baxter...</td>
#       <td>2021</td>
#       <td></td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>33824513</td>
#       <td>[PMC8023346]</td>
#       <td>Radical solutions.</td>
#       <td></td>
#       <td>2021</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>33773496</td>
#       <td>[PMC8083606]</td>
#       <td>SCENTinel 1.0: Development of a Rapid Test to ...</td>
#       <td>Parma V, Hannum ME, O'Leary M, Pellegrino R, R...</td>
#       <td>2021</td>
#       <td>Department of Psychology, Temple University, 1...</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td></td>
#       <td>[PPR251997]</td>
#       <td>&lt;i&gt;SCENTinel 1.0&lt;/i&gt;: development of a rapid t...</td>
#       <td>Parma V, Hannum ME, O’Leary M, Pellegrino R, R...</td>
#       <td>2020</td>
#       <td></td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>33073312</td>
#       <td>[PMC7568947]</td>
#       <td>SARS-CoV-2 pandemic: a review of molecular dia...</td>
#       <td>Jayamohan H, Lambert CJ, Sant HJ, Jafek A, Pat...</td>
#       <td>2021</td>
#       <td>Department of Mechanical Engineering, Universi...</td>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>32706958</td>
#       <td>[PMC7493127]</td>
#       <td>Rapid Scaling Up of Covid-19 Diagnostic Testin...</td>
#       <td>Tromberg BJ, Schwetz TA, Pérez-Stable EJ, Hode...</td>
#       <td>2020</td>
#       <td>From the National Institute of Biomedical Imag...</td>
#       <td>109</td>
#     </tr>
#   </tbody>
# </table>
# </div>
