# %% [markdown]
# # get_patent_info
# This notebook creates dataset-related node and relationship files for the RADx-KG:
# * Patent.csv
# * Researcher-IS_INVENTOR_OF-Patent
# * Patent-IS_RELATED_TO-Grant.csv

# %%
import os
import pandas as pd
import utils
import publication_query
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

# %%
KG_PATH = "../kg/data"

# %%
patent_info = pd.read_csv(
        "https://docs.google.com/spreadsheets/d/1O_IpO8-1IMHXmhpEw6eRU6KPNtBtnJ38GEL-tx9F9Mw/export?format=csv",
        keep_default_na=False,
       )

# %%
print(f"Number of projects {patent_info.shape[0]}")
patent_info
# Out:
# Number of projects 17
#    coreProjectNum  \
# 0     R01DE031114
# 1     U01HL152410
# 2     U01HL150852
# 3     R61HD105593
# 4     R61HD105590
# 5     R42DE030829
# 6     U18TR003780
# 7     U01AA029345
# 8     U18TR003807
# 9     U18TR003778
# 10    U18TR003795
# 11    U01DC019579
# 12    R44DE030852
# 13    U01AA029331
# 14    U01DC019573
# 15
# 16
#
#                                                                                                                      inventors  \
# 0                                                                                       Jesse Jokerst|Yash Mantri|Zhicheng Jin
# 1                                                                                          Jie Huang|Chen Zhu|Rex E Gerald, II
# 2                                                                       Edward P DeMauro|German Drazer|Hao Lin|Mehdi Javanmard
# 3                       Ananth Annapragada|Sridevi Devaraj|Devika Subramanian|Aadith Vittala|Xinpu Chen|Craig Rusin|Carl Allen
# 4                                                        Shamim Nemati|Supreeth Prajwal Shashikumar|Atul Malhotra|Jonathan Lam
# 5                                                                                             Roya Khosravi-Far|Ramin M Hakami
# 6                                                                                                                 Samarjit Das
# 7                                                                              Selma Piranej|Khalid Salaita|Alisina Bazrafshan
# 8                                                                                              Eduardo Reategui|Jingjing Zhang
# 9                                            David Wong|Feng Li|Fang Wei|Otto Yang|Jennifer Fulcher|David Chia|Samantha Chiang
# 10  Cristina E Davis|Michael K Levasseur|Raquel Cumeras|Yuriy Zrodnikov|Mitchell M McCartney|Alexander G Fung|Daniel J Peirano
# 11                                                                                           Mark William Albers|Colin Magdamo
# 12                                                                                     Xing Wang|Xiaohu Yao|Nicolas Letourneau
# 13                                           Benjamin Sumlin|Rajan Charkrabarty|Nishit Jaideep Shetty|John Cirrito|Carla Yuede
# 14                                                                            Steven Dunn Munger|John E Hayes|Richard C Gerkin
# 15                                                            Audrey Ragan Odom John|Amalia Zoraida Berna Perez|Elikplim Akaho
# 16                                                                                     Xing Wang|Xiaohu Yao|Nicolas Letourneau
#
#            patentId                                          patentUrl  \
# 0    WO2022169991A1   https://patents.google.com/patent/WO2022169991A1
# 1      US11740171B2     https://patents.google.com/patent/US11740171B2
# 2   US20220280062A1  https://patents.google.com/patent/US20220280062A1
# 3    WO2023049044A1   https://patents.google.com/patent/WO2023049044A1
# 4    WO2023009846A1   https://patents.google.com/patent/WO2023009846A1
# 5    WO2022204258A1   https://patents.google.com/patent/WO2022204258A1
# 6    WO2022178313A1   https://patents.google.com/patent/WO2022178313A1
# 7    WO2023192883A2   https://patents.google.com/patent/WO2023192883A2
# 8    WO2023114970A2   https://patents.google.com/patent/WO2023114970A2
# 9    WO2023137426A2   https://patents.google.com/patent/WO2023137426A2
# 10  US20220387924A1  https://patents.google.com/patent/US20220387924A1
# 11  US20230248297A1  https://patents.google.com/patent/US20230248297A1
# 12     WO2022109155   https://patents.google.com/patent/WO2022109155A1
# 13     WO2023192433   https://patents.google.com/patent/WO2023192433A1
# 14     WO2023278510   https://patents.google.com/patent/WO2023278510A1
# 15   WO2022094405A1   https://patents.google.com/patent/WO2022094405A1
# 16      EP4247971A1      https://patents.google.com/patent/EP4247971A1
#
#                                                                                                                    title  \
# 0        A face covering having a test strip for colorimetric monitoring of proteases and methods of detecting proteases
# 1                                                                      Open-ended hollow coaxial cable resonator sensor
# 2                                             Novel, Rapid Breathalyzer Diagnostic Device for the Presence of SARS-CoV-2
# 3                                                 Stratification of disease severity following an inflammatory condition
# 4                                                              Machine learning enabled patient stratification \n
# 5                                                                           Device and method for detecting inflammation
# 6                                                   Detecting diseases in subjects using extracelluar vesicles \n
# 7                                  Rolling sensor systems for detecting analytes and diagnostic methods related thereto
# 8     Single extracellular vesicle protein and rna assay via in-situ fluorescence microscopy in a uv micropattern array
# 9                                                Sars-cov-2 (covid-19) tests on saliva and blood using efirm technology
# 10                      Portable micro-preconcentrator to facilitate chemical sampling and subsequent analysis \n
# 11                        Systems and methods for administering a smell test for sars coronaviruses and covid-19 \n
# 12                             Polynucleotide nanostructures for detecting viral infections and other diseases \n
# 13           Rapid, single-use methods and systems for electrochemical analysis of pathogens in exhaled breath \n
# 14                                        Methods and techniques for processing responses of an olfactory test \n
# 15  \nBreath biomarkers of sars-cov-2 in children and methods of use thereof for the diagnosis and treatment of covid-19
# 16                                       Polynucleotide nanostructures for detecting viral infections and other diseases
#
#     filingDate grantedDate   status  \
# 0   2022-02-03              pending
# 1   2021-03-23  2023-08-29   active
# 2   2022-03-04              pending
# 3   2022-09-16              pending
# 4   2022-07-29              pending
# 5   2022-03-23              pending
# 6   2022-02-18              pending
# 7   2023-03-28              pending
# 8   2022-12-16              pending
# 9   2023-01-13              pending
# 10  2022-08-10              pending
# 11  2021-04-26              pending
# 12  2021-11-18              pending
# 13  2023-03-30              pending
# 14  2022-06-29              pending
# 15  2021-11-01              pending
# 16  2021-11-18              pending
#
#                                                                                                                                                       applicants
# 0                                                                                                                        Regents Of The University Of California
# 1                                                                                                                                  University of Missouri System
# 2                                                                                                                         Rutgers State University of New Jersey
# 3                                                                             Baylor College Of Medicine|Texas Children's Hospital|William Marsh Rice University
# 4                                                                                                                        Regents Of The University Of California
# 5                                                                                                                               InnoTech Precision Medicine, Inc
# 6                                                                                                                                   The Johns Hopkins University
# 7                                                                                                                                               Emory University
# 8                                                                                                                               Ohio State Innovation Foundation
# 9                                             The Regents Of The University Of California|The US Government as represented by the Department of Veterans Affairs
# 10                                                                                                                                      University of California
# 11                                                                                                                                         General Hospital Corp
# 12                                                                                        Atom Bioworks, Inc|The Board Of Trustees Of The University Of Illinois
# 13                                                                                                                                         Washington University
# 14  University Of Florida Research Foundation, Incorporated|Arizona Board Of Regents  On Behalf Of Arizona State University|The Penn State Research \nFoundation
# 15                                                                                                                       The Children's Hospital Of Philadelphia
# 16                                                                                                                      Atom Bioworks Inc|University of Illinois

# %%
patent_inventors = patent_info[["inventors", "patentId"]].copy()
patent_inventors["inventors"] = patent_inventors["inventors"].str.split("|")
patent_inventors = patent_inventors.explode("inventors")
#publication_query.expand_name_column(patent_inventors, "inventors")
#patent_inventors.rename(columns={"name": "inventor"}, inplace=True)
patent_grants = patent_info[["coreProjectNum", "patentId"]].copy()
patent = patent_info[["patentId", "title", "inventors", "filingDate", "grantedDate", "status", "applicants"]].copy()

# %%
investigators = pd.read_csv(os.path.join(KG_PATH, "nodes", "Researcher_investigators.csv"), dtype=str, keep_default_na=False)
other = pd.read_csv(os.path.join(KG_PATH, "nodes", "Researcher_primary_coauthors.csv"), dtype=str, keep_default_na=False)
researchers = pd.concat([investigators, other])
researchers.head()
# Out:
#                    id            name              fullName firstName  \
# 0   profileid:2563052        Allen CE          Carl E Allen      Carl
# 1   profileid:7039414  Annapragada AV  Ananth V Annapragada    Ananth
# 2  profileid:10320851       Bassiri H         Hamid Bassiri     Hamid
# 3   profileid:7989301        Burns JC          Jane C Burns      Jane
# 4   profileid:8667619         Chiu CY      Charles Yen Chiu   Charles
#
#   middleName     lastName                      orcid           profileId
# 0          E        Allen  orcid:0000-0002-6625-739X   profileid:2563052
# 1          V  Annapragada  orcid:0000-0002-3156-9617   profileid:7039414
# 2                 Bassiri  orcid:0000-0001-6532-8478  profileid:10320851
# 3          C        Burns  orcid:0000-0001-5679-1217   profileid:7989301
# 4        Yen         Chiu  orcid:0000-0003-2915-2094   profileid:8667619

# %%
investigators.head()
# Out:
#                    id            name              fullName firstName  \
# 0   profileid:2563052        Allen CE          Carl E Allen      Carl
# 1   profileid:7039414  Annapragada AV  Ananth V Annapragada    Ananth
# 2  profileid:10320851       Bassiri H         Hamid Bassiri     Hamid
# 3   profileid:7989301        Burns JC          Jane C Burns      Jane
# 4   profileid:8667619         Chiu CY      Charles Yen Chiu   Charles
#
#   middleName     lastName                      orcid           profileId
# 0          E        Allen  orcid:0000-0002-6625-739X   profileid:2563052
# 1          V  Annapragada  orcid:0000-0002-3156-9617   profileid:7039414
# 2                 Bassiri  orcid:0000-0001-6532-8478  profileid:10320851
# 3          C        Burns  orcid:0000-0001-5679-1217   profileid:7989301
# 4        Yen         Chiu  orcid:0000-0003-2915-2094   profileid:8667619

# %%
research_inventors = utils.fuzzy_merge(patent_inventors, researchers, left_fuzzy_on="inventors", right_fuzzy_on="fullName", how="left", threshold=0.95)

# %%
research_inventors.head()
# Out:
#        inventors        patentId         match  score                     id  \
# 0  Jesse Jokerst  WO2022169991A1                  0.0
# 1    Yash Mantri  WO2022169991A1   Yash Mantri    1.0    s2authorid:89826291
# 2   Zhicheng Jin  WO2022169991A1  Zhicheng Jin    1.0  s2authorid:2152843701
# 3   Zhicheng Jin  WO2022169991A1  Zhicheng Jin    1.0  s2authorid:1745180850
# 4   Zhicheng Jin  WO2022169991A1  Zhicheng Jin    1.0     s2authorid:2209272
#
#        name      fullName firstName middleName lastName orcid profileId
# 0
# 1  Mantri Y   Yash Mantri      Yash              Mantri
# 2     Jin Z  Zhicheng Jin  Zhicheng                 Jin
# 3     Jin Z  Zhicheng Jin  Zhicheng                 Jin
# 4     Jin Z  Zhicheng Jin  Zhicheng                 Jin

# %%
research_inventors_no_match = research_inventors.query("id == ''").copy()
research_inventors_no_match.head()
# Out:
#           inventors         patentId match  score id name fullName firstName  \
# 0     Jesse Jokerst   WO2022169991A1          0.0
# 6          Chen Zhu     US11740171B2          0.0
# 7  Rex E Gerald, II     US11740171B2          0.0
# 8  Edward P DeMauro  US20220280062A1          0.0
# 9     German Drazer  US20220280062A1          0.0
#
#   middleName lastName orcid profileId
# 0
# 6
# 7
# 8
# 9

# %%
researchers["firstLastName"] = researchers["firstName"] + " " + researchers["lastName"]
researchers.head()
# Out:
#                    id            name              fullName firstName  \
# 0   profileid:2563052        Allen CE          Carl E Allen      Carl
# 1   profileid:7039414  Annapragada AV  Ananth V Annapragada    Ananth
# 2  profileid:10320851       Bassiri H         Hamid Bassiri     Hamid
# 3   profileid:7989301        Burns JC          Jane C Burns      Jane
# 4   profileid:8667619         Chiu CY      Charles Yen Chiu   Charles
#
#   middleName     lastName                      orcid           profileId  \
# 0          E        Allen  orcid:0000-0002-6625-739X   profileid:2563052
# 1          V  Annapragada  orcid:0000-0002-3156-9617   profileid:7039414
# 2                 Bassiri  orcid:0000-0001-6532-8478  profileid:10320851
# 3          C        Burns  orcid:0000-0001-5679-1217   profileid:7989301
# 4        Yen         Chiu  orcid:0000-0003-2915-2094   profileid:8667619
#
#         firstLastName
# 0          Carl Allen
# 1  Ananth Annapragada
# 2       Hamid Bassiri
# 3          Jane Burns
# 4        Charles Chiu

# %%
publication_query.expand_name_column(research_inventors_no_match, "inventors")
research_inventors_no_match["inventor"] = research_inventors_no_match["firstName"] + " " + research_inventors_no_match["lastName"]

# %%
research_inventors_no_match = research_inventors_no_match[["inventors", "inventor", "patentId"]].copy()

# %%
research_inventors_no_match = utils.fuzzy_merge(research_inventors_no_match, researchers, left_fuzzy_on="inventor", right_fuzzy_on="firstLastName", how="left", threshold=0.96)

# %%
research_inventors_no_match.head()
# Out:
#           inventors        inventor         patentId           match  score  \
# 0     Jesse Jokerst   Jesse Jokerst   WO2022169991A1   Jesse Jokerst    1.0
# 1          Chen Zhu        Chen Zhu     US11740171B2                    0.0
# 2  Rex E Gerald, II          Rex II     US11740171B2                    0.0
# 3  Edward P DeMauro  Edward DeMauro  US20220280062A1  Edward DeMauro    1.0
# 4     German Drazer   German Drazer  US20220280062A1                    0.0
#
#                           id        name               fullName firstName  \
# 0         profileid:11288941  Jokerst JV  Jesse Vincent Jokerst     Jesse
# 1
# 2
# 3  orcid:0000-0002-3793-8014  DeMauro EP       Edward P DeMauro    Edward
# 4
#
#   middleName lastName                      orcid           profileId  \
# 0    Vincent  Jokerst  orcid:0000-0003-2829-6408  profileid:11288941
# 1
# 2
# 3          P  DeMauro  orcid:0000-0002-3793-8014
# 4
#
#     firstLastName
# 0   Jesse Jokerst
# 1
# 2
# 3  Edward DeMauro
# 4

# %% [markdown]
# ## Create Researcher-IS_INVENTOR-Patent relationships

# %%
research_inventors = research_inventors[["id", "patentId"]].copy()
research_inventors.query("id != ''", inplace=True)

# %%
research_inventors_no_match = research_inventors_no_match[["id", "patentId"]].copy()
research_inventors_no_match.query("id != ''", inplace=True)

# %%
research_inventors_matched = pd.concat([research_inventors, research_inventors_no_match])

# %%
research_inventors_matched.rename(columns={"id": "from", "patentId": "to"}, inplace=True)
research_inventors_matched.to_csv(os.path.join(KG_PATH, "relationships", "Researcher-IS_INVENTOR-Patent.csv"), index=False)
research_inventors_matched.head()
# Out:
#                         from              to
# 1        s2authorid:89826291  WO2022169991A1
# 2      s2authorid:2152843701  WO2022169991A1
# 3      s2authorid:1745180850  WO2022169991A1
# 4         s2authorid:2209272  WO2022169991A1
# 5  orcid:0000-0002-8659-2910    US11740171B2

# %% [markdown]
# ## Create Patent nodes

# %%
patent_map = {"patentId": "id", "title": "name", "inventors": "inventors", "filingDate": "filingDate",	"grantedDate": "grantedDate", "status": "status", "applicants": "applicants", "patentUrl": "url"}
patent = utils.rename_and_reorder_columns(patent_info, patent_map)

# %%
patent.to_csv(os.path.join(KG_PATH, "nodes", "Patent.csv"), index=False)
patent.head()
# Out:
#                 id  \
# 0   WO2022169991A1
# 1     US11740171B2
# 2  US20220280062A1
# 3   WO2023049044A1
# 4   WO2023009846A1
#
#                                                                                                               name  \
# 0  A face covering having a test strip for colorimetric monitoring of proteases and methods of detecting proteases
# 1                                                                Open-ended hollow coaxial cable resonator sensor
# 2                                       Novel, Rapid Breathalyzer Diagnostic Device for the Presence of SARS-CoV-2
# 3                                           Stratification of disease severity following an inflammatory condition
# 4                                                        Machine learning enabled patient stratification \n
#
#                                                                                                 inventors  \
# 0                                                                  Jesse Jokerst|Yash Mantri|Zhicheng Jin
# 1                                                                     Jie Huang|Chen Zhu|Rex E Gerald, II
# 2                                                  Edward P DeMauro|German Drazer|Hao Lin|Mehdi Javanmard
# 3  Ananth Annapragada|Sridevi Devaraj|Devika Subramanian|Aadith Vittala|Xinpu Chen|Craig Rusin|Carl Allen
# 4                                   Shamim Nemati|Supreeth Prajwal Shashikumar|Atul Malhotra|Jonathan Lam
#
#    filingDate grantedDate   status  \
# 0  2022-02-03              pending
# 1  2021-03-23  2023-08-29   active
# 2  2022-03-04              pending
# 3  2022-09-16              pending
# 4  2022-07-29              pending
#
#                                                                            applicants  \
# 0                                             Regents Of The University Of California
# 1                                                       University of Missouri System
# 2                                              Rutgers State University of New Jersey
# 3  Baylor College Of Medicine|Texas Children's Hospital|William Marsh Rice University
# 4                                             Regents Of The University Of California
#
#                                                  url
# 0   https://patents.google.com/patent/WO2022169991A1
# 1     https://patents.google.com/patent/US11740171B2
# 2  https://patents.google.com/patent/US20220280062A1
# 3   https://patents.google.com/patent/WO2023049044A1
# 4   https://patents.google.com/patent/WO2023009846A1
