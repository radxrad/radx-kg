# %% [markdown]
# # Get Author info from papers
# https://api.semanticscholar.org/api-docs/graph#tag/Paper-Data/operation/get_graph_get_paper_authors
#
# https://api.semanticscholar.org/api-docs/graph#tag/Author-Data/operation/post_graph_get_authors
#
# See also about PubMed unique author id:
# https://pubmed.ncbi.nlm.nih.gov/34180522/
# https://pubmed.ncbi.nlm.nih.gov/28960025/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5639053/
# https://github.com/Daniel-Mietchen/ideas/issues/1260
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5530597/

# %%
import os
import requests
import json
import pandas as pd
import publication_query
import utils

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_colwidth', None)

# %%
KG_PATH = "../kg/data"
DERIVED_DATA_PATH = "../derived_data"

# %%
START_PUBLICATION_YEAR = 2021 # Grants started at the end of 2020.

# %% [markdown]
# ## Get raw primary Publication data
# These publications result from a grant number query in PubMed.

# %%
raw_publications = pd.read_csv("https://raw.githubusercontent.com/christian-horgan/pubmed-search/main/data/radx-rad/article_data_current.csv", dtype=str, keep_default_na=False)

# %%
non_pubmed_publications = pd.read_csv("../data/Publications_non_pubmed.csv", dtype=str, keep_default_na=False)
non_pubmed_publications.head()
# Out:
#   pm_id                                              title pmc_id  \
# 0        IMI-CDE: an interactive interface for collabor...
#
#                                              authors  \
# 0  Tao S,Chou WC,Li J,Du J,Ram PM,Abeysinghe R,Xu...
#
#                                 doi  \
# 0  doi:10.1109/ICHI54592.2022.00070
#
#                                             keywords mesh_ids mesh_terms  \
# 0  COVID-19,Common Data Element,CDE,Mapping,Data ...
#
#                                             abstract project_serial_num  \
# 0  The National Institute of Health (NIH) launche...           LM013755
#
#                                         journal_name publication_year
# 0  2022 IEEE 10th International Conference on Hea...             2022

# %%
raw_publications = pd.concat([raw_publications, non_pubmed_publications])
raw_publications.fillna("", inplace=True)

# %%
# Restrict publications to 2021+ since RADx projects started at the end of 2020.
raw_publications["publication_year"] = raw_publications["publication_year"].astype(int)
raw_publications.query(f"publication_year >= {START_PUBLICATION_YEAR}", inplace=True)
# DOI is required as the primary key
raw_publications.dropna(subset="doi", inplace=True)
# convert property name to Neo4j convention
raw_publications.rename(columns={"pm_id": "pmId", "pmc_id": "pmcId", "project_serial_num": "projectSerialNum"}, inplace=True)

# %%
raw_publications.head()
# Out:
#        pmId                                              title        pmcId  \
# 0  37727605  Repurposing a SARS-CoV-2 surveillance program ...  PMC10505707
# 1  36595104  Ion-selective electrodes based on laser-induce...
# 2  36354449  An Experimental Framework for Developing Point...   PMC9688365
# 3  35992634  Development of a Biosensor Based on Angiotensi...   PMC9386735
# 4  35785019  Aerosol-jet-printed graphene electrochemical i...   PMC9245948
#
#                                              authors  \
# 0  ['King KL', 'Ham R', 'Smothers A', 'Lee I', 'B...
# 1  ['Soares RRA', 'Hjort RG', 'Pola CC', 'Jing D'...
# 2  ['Ullah SF', 'Moreira G', 'Datta SPA', 'McLamo...
# 3  ['Moreira G', 'Casso-Hartmann L', 'Datta SPA',...
# 4  ['Pola CC', 'Rangnekar SV', 'Sheets R', 'Szydl...
#
#                               doi  \
# 0  doi:10.3389/fpubh.2023.1168551
# 1  doi:10.1007/s00604-022-05615-9
# 2        doi:10.3390/bios12110938
# 3   doi:10.3389/fsens.2022.917380
# 4    doi:10.1088/2053-1583/ac7339
#
#                                             keywords  \
# 0  ['SARS-CoV-2', 'flu', 'influenza', 'saliva', '...
# 1  ['Electrochemical Sensors', 'Food additives', ...
# 2  ['SARS-CoV-2', 'analytical sensing', 'binding ...
# 3  ['LIG electrodes', 'attenuated virus', 'betaco...
# 4  ['COVID-19', 'aerosol jet printing', 'biosenso...
#
#                                             mesh_ids  \
# 0  ['D006801', 'D000086402', 'D014495', 'D0000863...
# 1  ['D006801', 'D017736', 'D006108', 'D009573', '...
# 2  ['D006801', 'D058266', 'D000086402', 'D0000863...
# 3                                                 []
# 4                                                 []
#
#                                           mesh_terms  \
# 0  ['Humans', 'SARS-CoV-2', 'Universities', 'COVI...
# 1  ['Humans', 'Ion-Selective Electrodes', 'Graphi...
# 2  ['Humans', 'Dielectric Spectroscopy', 'SARS-Co...
# 3                                                 []
# 4                                                 []
#
#                                             abstract projectSerialNum  \
# 0  Standard multiplex RT-qPCR diagnostic tests us...         AA029328
# 1  Nitrite is an important food additive for cure...         AA029328
# 2  Biolayer interferometry (BLI) is a well-establ...         AA029328
# 3  Severe acute respiratory syndrome coronavirus ...         AA029328
# 4  Rapid, inexpensive, and easy-to-use coronaviru...         AA029328
#
#                  journal_name  publication_year
# 0  Frontiers in public health              2023
# 1           Mikrochimica acta              2023
# 2                  Biosensors              2022
# 3        Frontiers in sensors              2022
# 4                2d materials              2022

# %%
raw_publications.tail()
# Out:
#          pmId                                              title        pmcId  \
# 400  35532905  Aptamer Sandwich Lateral Flow Assay (AptaFlow)...   PMC9112978
# 401  35132411  Outbreak.info Research Library: A standardized...   PMC8820656
# 402  34923447  Detecting model misconducts in decentralized h...  PMC10017272
# 403  34328683  Discovery and Characterization of Spike N-Term...   PMC8426805
# 0              IMI-CDE: an interactive interface for collabor...
#
#                                                authors  \
# 400  ['Yang LF', 'Kacherovsky N', 'Panpradist N', '...
# 401  ['Tsueng G', 'Mullen JL', 'Alkuzweny M', 'Cano...
# 402                               ['Kuo TT', 'Pham A']
# 403  ['Kacherovsky N', 'Yang LF', 'Dang HV', 'Cheng...
# 0    Tao S,Chou WC,Li J,Du J,Ram PM,Abeysinghe R,Xu...
#
#                                     doi  \
# 400    doi:10.1021/acs.analchem.2c00554
# 401       doi:10.1101/2022.01.20.477133
# 402  doi:10.1016/j.ijmedinf.2021.104658
# 403          doi:10.1002/anie.202107730
# 0      doi:10.1109/ICHI54592.2022.00070
#
#                                               keywords  \
# 400                                                 []
# 401                                                 []
# 402  ['Blockchain Distributed Ledger Technology', '...
# 403  ['SARS-CoV-2', 'aptamers', 'coronavirus', 'cry...
# 0    COVID-19,Common Data Element,CDE,Mapping,Data ...
#
#                                               mesh_ids  \
# 400  ['D000914', 'D052157', 'D000086382', 'D0000866...
# 401                                                 []
# 402                                                 []
# 403  ['D052157', 'D000086382', 'D004797', 'D006801'...
# 0
#
#                                             mesh_terms  \
# 400  ['Antibodies, Viral', 'Aptamers, Nucleotide', ...
# 401                                                 []
# 402                                                 []
# 403  ['Aptamers, Nucleotide', 'COVID-19', 'Enzyme-L...
# 0
#
#                                               abstract projectSerialNum  \
# 400  The COVID-19 pandemic is among the greatest he...         LM013755
# 401  To combat the ongoing COVID-19 pandemic, scien...         LM013755
# 402  To accelerate healthcare/genomic medicine rese...         LM013755
# 403  The coronavirus disease 2019 (COVID-19) pandem...         LM013755
# 0    The National Institute of Health (NIH) launche...         LM013755
#
#                                           journal_name  publication_year
# 400                               Analytical chemistry              2022
# 401          bioRxiv : the preprint server for biology              2022
# 402       International journal of medical informatics              2021
# 403   Angewandte Chemie (International ed. in English)              2021
# 0    2022 IEEE 10th International Conference on Hea...              2022

# %% [markdown]
# ## Get author information for the primary citations

# %%
# Query the Semantic Scholar API to get author information for a list of DOIs
raw_dois = list(raw_publications["doi"].unique())
authors = publication_query.get_author_ids(raw_dois)
authors.head()
# Out:
# Number of mismatches: 13
#      authorId                name                             aliases  \
# 0  2154342066        Kylie L King                        Kylie L King
# 1  2043300888       Rachel E. Ham            Rachel E Ham, Rachel Ham
# 2  2154336577  Austin R. Smothers  Austin R Smothers, Austin Smothers
# 3  2237391763           Isaac Lee
# 4  2237321471         Tyler Bowie
#
#   affiliations paperCount citationCount hIndex externalIds.DBLP  \
# 0           []          5            44      4              nan
# 1           []          6            22      3              nan
# 2           []          6            17      2              nan
# 3           []          1             0      0              nan
# 4           []          1             0      0              nan
#
#   externalIds.ORCID                                   paperId  \
# 0               nan  8a26272b10779c0d0cedc6eb4e2630d906429658
# 1               nan  8a26272b10779c0d0cedc6eb4e2630d906429658
# 2               nan  8a26272b10779c0d0cedc6eb4e2630d906429658
# 3               nan  8a26272b10779c0d0cedc6eb4e2630d906429658
# 4               nan  8a26272b10779c0d0cedc6eb4e2630d906429658
#
#                                                names      pmId     pmcId  \
# 0                      Kylie L King,nan,Kylie L King  37727605  10505707
# 1         Rachel E. Ham,nan,Rachel E Ham, Rachel Ham  37727605  10505707
# 2  Austin R. Smothers,nan,Austin R Smothers, Aust...  37727605  10505707
# 3                                     Isaac Lee,nan,  37727605  10505707
# 4                                   Tyler Bowie,nan,  37727605  10505707
#
#                               doi
# 0  doi:10.3389/fpubh.2023.1168551
# 1  doi:10.3389/fpubh.2023.1168551
# 2  doi:10.3389/fpubh.2023.1168551
# 3  doi:10.3389/fpubh.2023.1168551
# 4  doi:10.3389/fpubh.2023.1168551

# %%
# authors.query("doi == 'doi:10.1097/PCC.0000000000002976'") # Authors with title in names
authors.query("doi == 'doi:10.1109/ICHI54592.2022.00070'")
# Out:
#         authorId                name  \
# 5860     2463102        Shiqiang Tao
# 5861  2184490951       Wei–Chun Chou
# 5862  2117984733           Jianfu Li
# 5863     1728324        Jingcheng Du
# 5864  2184494110       Pritham M Ram
# 5865    39601718  Rashmie Abeysinghe
# 5866  2219752599              Hua Xu
# 5867   121147517      Xiaoqian Jiang
# 5868  2184494479        Peter W Rose
# 5869  1397958221     L. Ohno-Machado
# 5870   119557989      Guoqiang Zhang
#
#                                                 aliases  \
# 5860
# 5861
# 5862
# 5863                                      Jing-cheng Du
# 5864                                        Pritham Ram
# 5865
# 5866                                             Hua Xu
# 5867
# 5868                                         Peter Rose
# 5869  L Ohno-machado, L Ohno-machado, Lucila Ohno‐ma...
# 5870                   Guo-qiang Zhang, Guo–qiang Zhang
#
#                                            affiliations paperCount  \
# 5860                                                 []         46
# 5861                                                 []          1
# 5862                                                 []         16
# 5863  ['The University of Texas Health Science Cente...         74
# 5864                                                 []          2
# 5865                                                 []         30
# 5866                                                 []        236
# 5867                                                 []         89
# 5868                                                 []          4
# 5869                                                 []        545
# 5870                                                 []         77
#
#      citationCount hIndex                                   externalIds.DBLP  \
# 5860           771     11                                     ,Shiqiang Tao,
# 5861             0      0                                                nan
# 5862           163      8                                        ,Jianfu Li,
# 5863          1447     18                      ,Jing-Cheng Du, Jingcheng Du,
# 5864             1      1                                                nan
# 5865           119      7                               ,Rashmie Abeysinghe,
# 5866         10035     51                              ,Hua Xu, Hua Xu 0001,
# 5867           878     16                                   ,Xiaoqian Jiang,
# 5868            19      2                                                nan
# 5869         19167     61                              ,Lucila Ohno-Machado,
# 5870          1256     13  ,Guo-Qiang Zhang, Guo-Qiang Zhang 0001, Guoqia...
#
#         externalIds.ORCID                                   paperId  \
# 5860                  nan  f06d21eacb91120147bb8347fdeec956de1b6baf
# 5861                  nan  f06d21eacb91120147bb8347fdeec956de1b6baf
# 5862                  nan  f06d21eacb91120147bb8347fdeec956de1b6baf
# 5863  0000-0002-0322-4566  f06d21eacb91120147bb8347fdeec956de1b6baf
# 5864                  nan  f06d21eacb91120147bb8347fdeec956de1b6baf
# 5865                  nan  f06d21eacb91120147bb8347fdeec956de1b6baf
# 5866                  nan  f06d21eacb91120147bb8347fdeec956de1b6baf
# 5867                  nan  f06d21eacb91120147bb8347fdeec956de1b6baf
# 5868                  nan  f06d21eacb91120147bb8347fdeec956de1b6baf
# 5869                  nan  f06d21eacb91120147bb8347fdeec956de1b6baf
# 5870                  nan  f06d21eacb91120147bb8347fdeec956de1b6baf
#
#                                                   names pmId pmcId  \
# 5860                         Shiqiang Tao,Shiqiang Tao,
# 5861                                 Wei–Chun Chou,nan,
# 5862                               Jianfu Li,Jianfu Li,
# 5863  Jingcheng Du,Jing-Cheng Du, Jingcheng Du,Jing-...
# 5864                      Pritham M Ram,nan,Pritham Ram
# 5865             Rashmie Abeysinghe,Rashmie Abeysinghe,
# 5866                  Hua Xu,Hua Xu, Hua Xu 0001,Hua Xu
# 5867                     Xiaoqian Jiang,Xiaoqian Jiang,
# 5868                        Peter W Rose,nan,Peter Rose
# 5869  L. Ohno-Machado,Lucila Ohno-Machado,L Ohno-mac...
# 5870  Guoqiang Zhang,Guo-Qiang Zhang, Guo-Qiang Zhan...
#
#                                    doi
# 5860  doi:10.1109/ICHI54592.2022.00070
# 5861  doi:10.1109/ICHI54592.2022.00070
# 5862  doi:10.1109/ICHI54592.2022.00070
# 5863  doi:10.1109/ICHI54592.2022.00070
# 5864  doi:10.1109/ICHI54592.2022.00070
# 5865  doi:10.1109/ICHI54592.2022.00070
# 5866  doi:10.1109/ICHI54592.2022.00070
# 5867  doi:10.1109/ICHI54592.2022.00070
# 5868  doi:10.1109/ICHI54592.2022.00070
# 5869  doi:10.1109/ICHI54592.2022.00070
# 5870  doi:10.1109/ICHI54592.2022.00070

# %%
publication_query.expand_name_column(authors, "name")
authors.rename(columns={"name": "author"}, inplace=True)
authors.rename(columns={"externalIds.ORCID": "orcid"}, inplace=True)
authors = raw_publications.merge(authors, on="doi")

# %%
authors.drop_duplicates(inplace=True)
authors.fillna("", inplace=True)
authors.replace("nan", "", inplace=True)
authors.rename(columns={"name": "author"}, inplace=True)

# %% [markdown]
# ## Match publication authors with RADx-rad investigators
# In this step, we eliminate non-RADx publications.

# %%
radx_investigators = pd.read_csv(os.path.join(DERIVED_DATA_PATH, "radx_investigators.csv"))

# %%
radx_investigators.head()
# Out:
#     dbgapAccession coreProjectNum studyInvestigator   profileId  \
# 0  phs002964.v1.p1    U01DC019579          Albers M   6625336.0
# 1              NaN    R61HD105593               NaN   2563052.0
# 2  phs002585.v1.p1    R61HD105593     Annapragada A   7039414.0
# 3              NaN    U24LM013755               NaN  10450719.0
# 4              NaN    R33HD105594               NaN  10320851.0
#
#   projectSerialNum isContactPi  fiscalYear             grantPi  \
# 0         DC019579        True      2022.0           Albers MW
# 1         HD105593       False      2022.0            Allen CE
# 2         HD105593        True      2022.0      Annapragada AV
# 3         LM013755       False      2023.0  Aronoff-Spencer ES
# 4         HD105594       False      2023.0           Bassiri H
#
#                   fullName firstName middleName         lastName  isPi  \
# 0            Mark W Albers      Mark          W           Albers  True
# 1             Carl E Allen      Carl          E            Allen  True
# 2     Ananth V Annapragada    Ananth          V      Annapragada  True
# 3  Eliah S Aronoff-Spencer     Eliah          S  Aronoff-Spencer  True
# 4           Hamid  Bassiri     Hamid        NaN          Bassiri  True
#
#    isDepositor                name
# 0        False           Albers MW
# 1        False            Allen CE
# 2        False      Annapragada AV
# 3        False  Aronoff-Spencer ES
# 4        False           Bassiri H

# %% [markdown]
# #### Fuzzy merge of publication authors with RADx investigators

# %%
# The threshold was manually adjusted by checking for proper matches in the table below. The lowest threshold is 0.905882 for author Vanegas D.
radx_authors = utils.fuzzy_merge(authors[["author", "authorId", "aliases", "orcid", "projectSerialNum", "doi"]], 
                                    radx_investigators[["name", "projectSerialNum"]], 
                                    left_fuzzy_on="author", right_fuzzy_on="name", 
                                    left_on="projectSerialNum", right_on="projectSerialNum", 
                                    how="inner", threshold=0.905)

# %%
print("Matched authors       :", radx_authors.shape[0])
print("Matched unique authors:", radx_authors["author"].nunique())
print("Number of unique DOIs :", radx_authors["doi"].nunique())
radx_authors.head()
# Out:
# Matched authors       : 303
# Matched unique authors: 63
# Number of unique DOIs : 205
#       author  authorId                                            aliases  \
# 0  Vanegas D  30717980  Diana C Vanegas, D C Vanegas, Diana C Vanegas,...
# 1  Vanegas D  30717980  Diana C Vanegas, D C Vanegas, Diana C Vanegas,...
# 2  Vanegas D  30717980  Diana C Vanegas, D C Vanegas, Diana C Vanegas,...
# 3  Cirrito J   5588350  J R Cirrito, John R Cirrito, John Cirrito, Joh...
# 4  Cirrito J   5588350  J R Cirrito, John R Cirrito, John Cirrito, Joh...
#
#   orcid projectSerialNum                             doi              match  \
# 0               AA029328        doi:10.3390/bios12110938  Vanegas-Gamboa DC
# 1               AA029328   doi:10.3389/fsens.2022.917380  Vanegas-Gamboa DC
# 2               AA029328        doi:10.3390/bios12020101  Vanegas-Gamboa DC
# 3               AA029331  doi:10.1021/acssensors.3c00512         Cirrito JR
# 4               AA029331  doi:10.1038/s41467-023-39419-z         Cirrito JR
#
#       score               name
# 0  0.905882  Vanegas-Gamboa DC
# 1  0.905882  Vanegas-Gamboa DC
# 2  0.905882  Vanegas-Gamboa DC
# 3  0.980000         Cirrito JR
# 4  0.980000         Cirrito JR

# %%
radx_authors.query("doi == 'doi:10.1109/ICHI54592.2022.00070'")
# Out:
#              author    authorId  \
# 301            Xu H  2219752599
# 302  Ohno-Machado L  1397958221
#
#                                                aliases orcid projectSerialNum  \
# 301                                             Hua Xu               LM013755
# 302  L Ohno-machado, L Ohno-machado, Lucila Ohno‐ma...               LM013755
#
#                                   doi           match  score            name
# 301  doi:10.1109/ICHI54592.2022.00070            Xu H    1.0            Xu H
# 302  doi:10.1109/ICHI54592.2022.00070  Ohno-Machado L    1.0  Ohno-Machado L

# %% [markdown]
# #### If there are multiple name matches for a publication, use the match with the highest score.

# %%
# sort descending so the match with the highest score comes first.
radx_authors.sort_values(by=["score", "doi", "match"], ascending=False, inplace=True)
# keep only the first instance for each match, thus eliminating the lower-scoring matches.
radx_authors.drop_duplicates(subset=["doi", "match"], inplace=True)
print("Matched authors       :", radx_authors.shape[0])
print("Matched unique authors:", radx_authors["author"].nunique())
print("Number of unique DOIs :", radx_authors["doi"].nunique())
radx_authors.head()
# Out:
# Matched authors       : 303
# Matched unique authors: 63
# Number of unique DOIs : 205
#               author    authorId  \
# 232  Solo-Gabriele H  1398411589
# 230  Solo-Gabriele H  1398411589
# 224  Solo-Gabriele H  1398411589
# 281        Varsani A     4462013
# 283         Scotch M     2161990
#
#                                                aliases orcid projectSerialNum  \
# 232  Helena Solo‐gabriele, Helena Maria Solo-gabrie...               DA053941
# 230  Helena Solo‐gabriele, Helena Maria Solo-gabrie...               DA053941
# 224  Helena Solo‐gabriele, Helena Maria Solo-gabrie...               DA053941
# 281             A U Varsani, A Varsani, Arvind Varsani               LM013129
# 283         M Scotch, Matthew L Scotch, Matthew Scotch               LM013129
#
#                              doi            match  score             name
# 232  doi:10.7171/jbt.21-3203-019  Solo-Gabriele H    1.0  Solo-Gabriele H
# 230  doi:10.7171/jbt.21-3203-017  Solo-Gabriele H    1.0  Solo-Gabriele H
# 224        doi:10.3390/w14081187  Solo-Gabriele H    1.0  Solo-Gabriele H
# 281        doi:10.3390/v13091803        Varsani A    1.0        Varsani A
# 283        doi:10.3390/v13091803         Scotch M    1.0         Scotch M

# %% [markdown]
# #### Filter publications (RADx investigators only)

# %%
primary_dois = list(radx_authors["doi"].unique())
primary_publications = raw_publications[raw_publications["doi"].isin(set(primary_dois))].copy()
primary_publications.fillna("", inplace=True)
primary_publications.head()
# Out:
#        pmId                                              title        pmcId  \
# 2  36354449  An Experimental Framework for Developing Point...   PMC9688365
# 3  35992634  Development of a Biosensor Based on Angiotensi...   PMC9386735
# 5  35200361       Context-Aware Diagnostic Specificity (CADS).   PMC8869940
# 6  37498298  Rapid Direct Detection of SARS-CoV-2 Aerosols ...  PMC10463275
# 7  37429842  Real-time environmental surveillance of SARS-C...  PMC10333287
#
#                                              authors  \
# 2  ['Ullah SF', 'Moreira G', 'Datta SPA', 'McLamo...
# 3  ['Moreira G', 'Casso-Hartmann L', 'Datta SPA',...
# 5  ['McLamore ES', 'Moreira G', 'Vanegas DC', 'Da...
# 6  ['Ghumra DP', 'Shetty N', 'McBrearty KR', 'Put...
# 7  ['Puthussery JV', 'Ghumra DP', 'McBrearty KR',...
#
#                               doi  \
# 2        doi:10.3390/bios12110938
# 3   doi:10.3389/fsens.2022.917380
# 5        doi:10.3390/bios12020101
# 6  doi:10.1021/acssensors.3c00512
# 7  doi:10.1038/s41467-023-39419-z
#
#                                             keywords  \
# 2  ['SARS-CoV-2', 'analytical sensing', 'binding ...
# 3  ['LIG electrodes', 'attenuated virus', 'betaco...
# 5                                                 []
# 6  ['SARS-CoV-2', 'aerosol science', 'biosensors'...
# 7                                                 []
#
#                                             mesh_ids  \
# 2  ['D006801', 'D058266', 'D000086402', 'D0000863...
# 3                                                 []
# 5       ['D006801', 'D015233', 'D011506', 'D012680']
# 6  ['D006801', 'D000086402', 'D000086382', 'D0190...
# 7  ['D006801', 'D000086402', 'D000086382', 'D0588...
#
#                                           mesh_terms  \
# 2  ['Humans', 'Dielectric Spectroscopy', 'SARS-Co...
# 3                                                 []
# 5  ['Humans', 'Models, Statistical', 'Proteins', ...
# 6  ['Humans', 'SARS-CoV-2', 'COVID-19', 'Point-of...
# 7  ['Humans', 'SARS-CoV-2', 'COVID-19', 'Pandemic...
#
#                                             abstract projectSerialNum  \
# 2  Biolayer interferometry (BLI) is a well-establ...         AA029328
# 3  Severe acute respiratory syndrome coronavirus ...         AA029328
# 5  Rapid detection of proteins is critical in a v...         AA029328
# 6  Airborne transmission via virus-laden aerosols...         AA029331
# 7  Real-time surveillance of airborne SARS-CoV-2 ...         AA029331
#
#             journal_name  publication_year
# 2             Biosensors              2022
# 3   Frontiers in sensors              2022
# 5             Biosensors              2022
# 6            ACS sensors              2023
# 7  Nature communications              2023

# %% [markdown]
# ## Create primary ```Publication``` node file for KG

# %%
primary_publications["id"] = primary_publications["doi"]
primary_publications["url"] = "https://doi.org/" + primary_publications["doi"]
primary_publications["type"] = "primary"
primary_publications.drop_duplicates("id", inplace=True)

# %%
publication_map = {"id": "id", "title": "name", "abstract": "abstract", "journal_name": "journal", "publication_year": "year", "type": "type", "doi": "doi", "pmId": "pmId", "pmcId": "pmcId", "url": "url"}
primary_publications_kg = utils.rename_and_reorder_columns(primary_publications, publication_map)

# %%
primary_publications_kg.to_csv(os.path.join(KG_PATH, "nodes", "Publication_primary.csv"), index=False)

# %% [markdown]
# ### Create primary publication Author nodes

# %%
primary_authors_all = authors[authors["doi"].isin(set(primary_dois))].copy()
primary_authors_all["fullName"] = primary_authors_all["fullName"].str.replace(".", "")
primary_authors_all.head()
# Out:
#       pmId_x                                              title     pmcId_x  \
# 15  36354449  An Experimental Framework for Developing Point...  PMC9688365
# 16  36354449  An Experimental Framework for Developing Point...  PMC9688365
# 17  36354449  An Experimental Framework for Developing Point...  PMC9688365
# 18  36354449  An Experimental Framework for Developing Point...  PMC9688365
# 19  36354449  An Experimental Framework for Developing Point...  PMC9688365
#
#                                               authors  \
# 15  ['Ullah SF', 'Moreira G', 'Datta SPA', 'McLamo...
# 16  ['Ullah SF', 'Moreira G', 'Datta SPA', 'McLamo...
# 17  ['Ullah SF', 'Moreira G', 'Datta SPA', 'McLamo...
# 18  ['Ullah SF', 'Moreira G', 'Datta SPA', 'McLamo...
# 19  ['Ullah SF', 'Moreira G', 'Datta SPA', 'McLamo...
#
#                          doi  \
# 15  doi:10.3390/bios12110938
# 16  doi:10.3390/bios12110938
# 17  doi:10.3390/bios12110938
# 18  doi:10.3390/bios12110938
# 19  doi:10.3390/bios12110938
#
#                                              keywords  \
# 15  ['SARS-CoV-2', 'analytical sensing', 'binding ...
# 16  ['SARS-CoV-2', 'analytical sensing', 'binding ...
# 17  ['SARS-CoV-2', 'analytical sensing', 'binding ...
# 18  ['SARS-CoV-2', 'analytical sensing', 'binding ...
# 19  ['SARS-CoV-2', 'analytical sensing', 'binding ...
#
#                                              mesh_ids  \
# 15  ['D006801', 'D058266', 'D000086402', 'D0000863...
# 16  ['D006801', 'D058266', 'D000086402', 'D0000863...
# 17  ['D006801', 'D058266', 'D000086402', 'D0000863...
# 18  ['D006801', 'D058266', 'D000086402', 'D0000863...
# 19  ['D006801', 'D058266', 'D000086402', 'D0000863...
#
#                                            mesh_terms  \
# 15  ['Humans', 'Dielectric Spectroscopy', 'SARS-Co...
# 16  ['Humans', 'Dielectric Spectroscopy', 'SARS-Co...
# 17  ['Humans', 'Dielectric Spectroscopy', 'SARS-Co...
# 18  ['Humans', 'Dielectric Spectroscopy', 'SARS-Co...
# 19  ['Humans', 'Dielectric Spectroscopy', 'SARS-Co...
#
#                                              abstract projectSerialNum  \
# 15  Biolayer interferometry (BLI) is a well-establ...         AA029328
# 16  Biolayer interferometry (BLI) is a well-establ...         AA029328
# 17  Biolayer interferometry (BLI) is a well-establ...         AA029328
# 18  Biolayer interferometry (BLI) is a well-establ...         AA029328
# 19  Biolayer interferometry (BLI) is a well-establ...         AA029328
#
#    journal_name  publication_year  authorId      author  \
# 15   Biosensors              2022  66615195    Ullah SF
# 16   Biosensors              2022  14596380   Moreira G
# 17   Biosensors              2022   5237978     Datta S
# 18   Biosensors              2022   5655264  McLamore E
# 19   Biosensors              2022  30717980   Vanegas D
#
#                                               aliases affiliations paperCount  \
# 15                    Sadia Fida Ullah, Sadia F Ullah           []         17
# 16  Geisianny Moreira, Geisianny Augusta Monteiro ...           []         13
# 17  Shoumen Datta, Shoumen P A Datta, Shoumen Pa D...           []         84
# 18  E S Mclamore, E S Mclamore, Ericz Mclamore, Er...           []        164
# 19  Diana C Vanegas, D C Vanegas, Diana C Vanegas,...           []         41
#
#    citationCount hIndex                             externalIds.DBLP orcid  \
# 15           164      7
# 16            66      4
# 17           349     10  ,Shoumen Datta, Shoumen Palit Austin Datta,
# 18          3088     30                            ,Eric S McLamore,
# 19           660     14                              ,Diana Vanegas,
#
#                                      paperId  \
# 15  7100d14b3fd28ec25980f0fa3253d86fd33cfef9
# 16  7100d14b3fd28ec25980f0fa3253d86fd33cfef9
# 17  7100d14b3fd28ec25980f0fa3253d86fd33cfef9
# 18  7100d14b3fd28ec25980f0fa3253d86fd33cfef9
# 19  7100d14b3fd28ec25980f0fa3253d86fd33cfef9
#
#                                                 names    pmId_y  pmcId_y  \
# 15    S. F. Ullah,nan,Sadia Fida Ullah, Sadia F Ullah  36354449  9688365
# 16  G. Moreira,nan,Geisianny Moreira, Geisianny Au...  36354449  9688365
# 17  S. Datta,Shoumen Datta, Shoumen Palit Austin D...  36354449  9688365
# 18  E. McLamore,Eric S McLamore,E S Mclamore, E S ...  36354449  9688365
# 19  D. Vanegas,Diana Vanegas,Diana C Vanegas, D C ...  36354449  9688365
#
#       fullName firstName middleName  lastName
# 15   S F Ullah         S          F     Ullah
# 16   G Moreira         G              Moreira
# 17     S Datta         S                Datta
# 18  E McLamore         E             McLamore
# 19   D Vanegas         D              Vanegas

# %%
#primary_authors[["authorId", "author", "fullName", "firstName", "middleName", "lastName", "doi"]].to_csv(os.path.join(DERIVED_DATA_PATH, "primary_authors_all.csv"), index=False)

# %% [markdown]
# ## Create ```Publication-CITES-Publication``` relationship file for KG

# %%
citations = publication_query.get_citations(primary_dois)
citations.rename(columns={"doiCite": "from", "doi": "to"}, inplace=True)
# TODO where does the following inconsistency originate?
# WARNING: Error messages from data import:
# doi:10.47464/METROCIENCIA/VOL29/3/2021/5-10 (Publication-ID)-[CITES]->doi:10.1002/art.41616 (Publication-ID) referring to missing node doi:10.47464/METROCIENCIA/VOL29/3/2021/5-10
citations = citations[(citations["from"] != "doi:10.47464/METROCIENCIA/VOL29/3/2021/5-10") & (citations["to"] != "doi:10.1002/art.41616")]
citations.to_csv(os.path.join(KG_PATH, "relationships", "Publication-CITES-Publication.csv"), index=False)

# %% [markdown]
# ## Get Secondary publications
# Secondary publications are publications that cite the primary publication

# %%
secondary_dois = list(citations["from"].unique())
# remove any primary DOIs, e.g., a primary publication cites another primary publication.
secondary_dois = list(set(secondary_dois) - set(primary_dois))
secondary_publications = publication_query.get_publication_info(secondary_dois)

# %%
secondary_publications["id"] = secondary_publications["doi"]
secondary_publications["url"] = "https://doi.org/" + secondary_publications["doi"]
secondary_publications["type"] = "secondary"
secondary_publications.drop_duplicates("id", inplace=True)

# %%
citation_map = {"id": "id", "title": "name", "abstract": "abstract", "journal": "journal", "year": "year", "type": "type", "doi": "doi", "pmId": "pmId", "pmcId": "pmcId", "url": "url"}
secondary_publications = utils.rename_and_reorder_columns(secondary_publications, citation_map)

# %%
print("Number of secondary publications:", secondary_publications.shape[0])
secondary_publications.head()
# Out:
# Number of secondary publications: 1807
#                                   id  \
# 0     doi:10.21203/RS.3.RS-721043/V1
# 1        doi:10.15562/ism.v14i1.1632
# 2             doi:10.1002/rth2.12747
# 3              doi:10.1111/jpc.15715
# 4  doi:10.1080/17474124.2023.2295496
#
#                                                 name  \
# 0  SARS-CoV-2 gained the unique spike protein S1-...
# 1  Penegakkan diagnosis lupus eritematosus sistem...
# 2  Illustrated State‐of‐the‐Art Capsules of the I...
# 3  Acute Renal Failure Requiring Renal Replacemen...
# 4  Risankizumab to treat moderately to severely a...
#
#                                             abstract  \
# 0  \n The clue behind the emergence of SARS-CoV-2...
# 1  Background: Systemic lupus erythematosus (SLE)...
# 2  The ISTH London 2022 Congress is the first hel...
# 3  An 18-month-boy presented with fever for 7 day...
# 4  INTRODUCTION\nRisankizumab is a humanized mono...
#
#                                              journal  year       type  \
# 0                                                     2021  secondary
# 1                               Intisari Sains Medis  2023  secondary
# 2  Research and Practice in Thrombosis and Haemos...  2022  secondary
# 3            Journal of Paediatrics and Child Health  2021  secondary
# 4     Expert review of gastroenterology & hepatology  2023  secondary
#
#                                  doi      pmId    pmcId  \
# 0     doi:10.21203/RS.3.RS-721043/V1
# 1        doi:10.15562/ism.v14i1.1632
# 2             doi:10.1002/rth2.12747  35814801  9257378
# 3              doi:10.1111/jpc.15715  34467603
# 4  doi:10.1080/17474124.2023.2295496  38095092
#
#                                                  url
# 0     https://doi.org/doi:10.21203/RS.3.RS-721043/V1
# 1        https://doi.org/doi:10.15562/ism.v14i1.1632
# 2             https://doi.org/doi:10.1002/rth2.12747
# 3              https://doi.org/doi:10.1111/jpc.15715
# 4  https://doi.org/doi:10.1080/17474124.2023.2295496

# %%
secondary_publications.to_csv(os.path.join(KG_PATH, "nodes", "Publication_secondary.csv"), index=False)

# %% [markdown]
# ### Create list of primary Authors

# %%
radx_authors.head()
# Out:
#               author    authorId  \
# 232  Solo-Gabriele H  1398411589
# 230  Solo-Gabriele H  1398411589
# 224  Solo-Gabriele H  1398411589
# 281        Varsani A     4462013
# 283         Scotch M     2161990
#
#                                                aliases orcid projectSerialNum  \
# 232  Helena Solo‐gabriele, Helena Maria Solo-gabrie...               DA053941
# 230  Helena Solo‐gabriele, Helena Maria Solo-gabrie...               DA053941
# 224  Helena Solo‐gabriele, Helena Maria Solo-gabrie...               DA053941
# 281             A U Varsani, A Varsani, Arvind Varsani               LM013129
# 283         M Scotch, Matthew L Scotch, Matthew Scotch               LM013129
#
#                              doi            match  score             name
# 232  doi:10.7171/jbt.21-3203-019  Solo-Gabriele H    1.0  Solo-Gabriele H
# 230  doi:10.7171/jbt.21-3203-017  Solo-Gabriele H    1.0  Solo-Gabriele H
# 224        doi:10.3390/w14081187  Solo-Gabriele H    1.0  Solo-Gabriele H
# 281        doi:10.3390/v13091803        Varsani A    1.0        Varsani A
# 283        doi:10.3390/v13091803         Scotch M    1.0         Scotch M

# %%
primary_authors = radx_authors[["authorId", "author", "aliases", "projectSerialNum", "doi"]].copy()

# %%
primary_authors.drop_duplicates(inplace=True)
primary_authors.dropna(inplace=True)
primary_authors.sort_values("author", inplace=True)
print(primary_authors.shape[0])
primary_authors.head()
# Out:
# 303
#      authorId         author  \
# 102  48292006        Allen C
# 103   3473746  Annapragada A
# 105   3473746  Annapragada A
# 107   3473746  Annapragada A
# 113   3473746  Annapragada A
#
#                                                aliases projectSerialNum  \
# 102  C Allen, Carl E Allen, Carl Allen, Carl E Alle...         HD105593
# 103  Ananth V Annapragada, A Annapragada, A V Annap...         HD105593
# 105  Ananth V Annapragada, A Annapragada, A V Annap...         HD105593
# 107  Ananth V Annapragada, A Annapragada, A V Annap...         HD105593
# 113  Ananth V Annapragada, A Annapragada, A V Annap...         HD105593
#
#                                   doi
# 102           doi:10.3390/jcm12175435
# 103           doi:10.3390/jcm12175435
# 105  doi:10.1097/INF.0000000000003888
# 107    doi:10.1038/s41390-022-02108-6
# 113     doi:10.1016/j.jbi.2021.103818

# %%
primary_authors.to_csv(os.path.join("../derived_data/", "primary_authors.csv"), index=False)

# %% [markdown]
# ## Create a list of primary authors who are not PIs or Study Investigators

# %%
primary_authors_list = list(primary_authors["authorId"].unique())

# %%
primary_authors_all_list = list(primary_authors_all["authorId"].unique())
primary_authors_other_list = set(primary_authors_all_list) - set(primary_authors_list)

# %%
primary_authors_other = primary_authors_all[primary_authors_all["authorId"].isin(primary_authors_other_list)]
primary_authors_other = primary_authors_other[["authorId", "author", "fullName", "firstName", "middleName", "lastName", "doi"]].copy()
primary_authors_other.drop_duplicates(inplace=True)
primary_authors_other.dropna(inplace=True)
primary_authors_other.sort_values("author", inplace=True)

# %%
primary_authors_other.to_csv(os.path.join("../derived_data/", "primary_authors_other.csv"), index=False)
print(f"Number of other primary paper authors: {primary_authors_other.shape[0]}")
primary_authors_other.head()
# Out:
# Number of other primary paper authors: 3186
#         authorId            author  \
# 2464        None   ONJEBAREMEABCFK
# 4651    80827919        Abdullah N
# 3441  2186155180             Abe N
# 3614  2186155180             Abe N
# 4230     6865020   Abedalthagafi M
#
#                                                fullName firstName  \
# 2464  Olivia Neha Jordan E Brandi Anita Rachel Evera...    Olivia
# 4651                                   Natasha Abdullah   Natasha
# 3441                                          Naomi Abe     Naomi
# 3614                                          Naomi Abe     Naomi
# 4230                                    M Abedalthagafi         M
#
#                                              middleName       lastName  \
# 2464  NehaJordanEBrandiAnitaRachelEverardoMaryEAlmen...
# 4651                                                          Abdullah
# 3441                                                               Abe
# 3614                                                               Abe
# 4230                                                     Abedalthagafi
#
#                                     doi
# 2464     doi:10.1038/s41586-023-05949-1
# 4651     doi:10.1016/j.cell.2021.05.002
# 3441     doi:10.1038/s41467-022-30357-w
# 3614  doi:10.1016/S2589-7500(22)00149-2
# 4230     doi:10.1038/s41592-022-01444-z

# %% [markdown]
# ### Create list of secondary authors

# %%
# secondary_authors = publication_query.get_author_ids(secondary_dois)
# author_map = {"authorId": "authorId", "title": "name", "abstract": "abstract", "journal": "journal", "year": "year", "type": "type", "doi": "doi", "pmId": "pmId", "pmcId": "pmcId", "url": "url"}
# secondary_authors = utils.rename_and_reorder_columns(secondary_authors, author_map)
# secondary_authors.rename(columns={"name": "author"})
# secondary_authors.head()
#secondary_authors = authors[["authorId", "author", "aliases", "orcid", "projectSerialNum"]].copy()

# %%
#secondary_authors.to_csv(os.path.join("../derived_data/", "secondary_authors.csv"), index=False)
